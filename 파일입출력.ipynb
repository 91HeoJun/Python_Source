# %% [markdown]
# ## 파일 출력

# %%
f = open("data/test1.txt","w")
print(dir(f))
f.close()
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
f = open("data/test1.txt","w",encoding="utf-8")
f.write("안녕하세요\n만나서 반갑습니다.")
f.close()

# %%
f = open("data/test1.txt","w",encoding="utf-8")
for i in range(1,11):
    data = "%d번째 줄입니다.\n" % i
    f.write(data)
f.close()

# %%
f = open("data/test1.txt","a",encoding="utf-8")
for i in range(1,11):
    data = "안녕하세요\n"
    f.write(data)
f.close()

# %%
# 리스트 값 파일에 쓰기
f = open("data/test1.txt","a",encoding="utf-8")
list1 = ["kim\n","park\n","choi\n"]
f.writelines(list1)
f.close()

# %%
# close() 자동으로 처리

with open("data/test1.txt","a",encoding="utf-8") as f:
    list1 = ["kim\n","park\n","choi\n"]
    f.writelines(list1)

# %%
with open("data/dict1.txt", "w", encoding="utf-8") as f:
    dict1 = {"name":"hong", "age":25, "add":"서울"}
    for k,v in dict1.items():
        f.writelines("{}: {}\n".format(k,v))

# %%
# 1000명의 키와 몸무게를 랜덤하게 생성해 파일에 기록하기

import random

# list() => 괄호안의 데이터들을 리스트로 생성
hanguls = list("가나다라마바사아자차카타파하")

with open("data/info.txt", "w", encoding="utf-8") as f:
    for i in range(1000):
        # choice() : 리스트중에서 아무 원소나 하나 추출
        name = random.choice(hanguls) + random.choice(hanguls)
        weight = random.randrange(40, 100) # 40이상 100미만 randrange = 범위 설정
        height = random.randrange(140, 200)
        f.writelines("{}, {}, {}\n".format(name, weight, height))

# %% [markdown]
# ## 파일 입력

# %%
f = open("data/review.txt", "r", encoding="utf-8")
content = f.read()
print(content)
f.close()
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
with open("data/review.txt", "r", encoding="utf-8") as f:
    content = f.read()
    print(content)
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
with open("data/review.txt", "r", encoding="utf-8") as f:
    for c in f:
        #print(c) = 엔터 포함
        print(c.strip()) #엔터 제거
# Out:
# The film, projected in the form of animation,
# imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,
# which eventually paves the path for gaining a fresh perspective on an age-old problem.
# The story also happens to centre around two parallel characters, Shundi King and Hundi King,
# who are twins, but they constantly fight over unresolved issues planted in their minds
# by external forces from within their very own units.

# %%
with open("data/review.txt", "r", encoding="utf-8") as f:
    line = f.readline() # 줄단위로 읽어오기
    print(line)
# Out:
# The film, projected in the form of animation,

# %%
with open("data/review.txt", "r", encoding="utf-8") as f:
    print(f.readlines()) # 결과를 리스트로 돌려받기
# Out:
# ['The film, projected in the form of animation,\n', 'imparts the lesson of how wars can be eluded through reasoning and peaceful dialogues,\n', 'which eventually paves the path for gaining a fresh perspective on an age-old problem.\n', 'The story also happens to centre around two parallel characters, Shundi King and Hundi King,\n', 'who are twins, but they constantly fight over unresolved issues planted in their minds\n', 'by external forces from within their very own units.\n']

# %%
# 리스트 생성
score = []

with open("data/score.txt", "r", encoding="utf-8") as f:
    for num in f:
        score.append(int(num))
    print(score)
    
    
# 총점과 평균을 구한 후 출력하기
print("총점 :{}".format(sum(score)))
print("평균 :{}".format(sum(score) / len(score)))
# Out:
# [95, 78, 92, 89, 100, 66]
# 총점 :520
# 평균 :86.66666666666667

# %%
# score.txt 를 읽어서 총점과 평균을 구해서 result.txt 파일에 쓰기
with open("data/score.txt", "r", encoding="utf-8") as f:
    for num in f:
        score.append(int(num))
    print(score)
    
with open("data/result.txt", "w", encoding="utf-8") as f1:
    f1.write("총점: {}\n".format(sum(score)))
    f1.write("평균: {:0.2f}".format(sum(score) / len(score)))
# Out:
# [95, 78, 92, 89, 100, 66, 95, 78, 92, 89, 100, 66, 95, 78, 92, 89, 100, 66]

# %%
import os

content = ""
fName = ""

fName = input("파일명을 입력해 주세요")
path = "data/"+fName

if os.path.exists(path):
    with open(path, "r", encoding="utf-8") as inFp:
        content = inFp.read()
        
    oName = input("저장할 폴더와 이름을 입력하세요 ")
    
    with open(oName, "w", encoding="utf-8") as outFp:
        outFp.writelines(content)
        
else:
    print("%s 파일이 없습니다." % fName)
# Out:
# 파일명을 입력해 주세요dict1.txt
# 저장할 폴더와 이름을 입력하세요 D:\pictures
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-37-47bc2e9e9d3c> in <module>
#      13     oName = input("저장할 폴더와 이름을 입력하세요 ")
#      14
# ---> 15     with open(oName, "w", encoding="utf-8") as outFp:
#      16         outFp.writelines(content)
#      17
#
# PermissionError: [Errno 13] Permission denied: 'D:\\pictures'

# %%
# info.txt 파일을 읽어서 BMI 지수를 계산한 후 출력하기
# bmi = 몸무게 / (키/100) ** 2
# 계산값이 >= 25 과체중, >=18.5 정상체중, 저체중

# 출력문
# 이름 : 
# 몸무게 :
# 키 : 
# BMI : 계산값 출력
# 결과 : 과체중

with open("data/info.txt", "r", encoding="utf-8") as f:
    for person in f:
        name, weight, height = person.strip().split(", ")
        
        BMI = int(weight) / (int(height) / 100) ** 2
        result = ""
        if 25 <= BMI:
            result = "과체중"
        elif 18.5 <= BMI:
            result = "정상체중"
        else:
            result = "저체중"
        
        print("이름: {}".format(name))
        print("몸무게: {}".format(weight))
        print("키: {}".format(height))
        print("BMI: {:0.2f}".format(BMI))
        print("결과: {}".format(result))

        print()
# Out:
# 이름: 마다
# 몸무게: 78
# 키: 190
# BMI: 21.61
# 결과: 정상체중
#
# 이름: 마바
# 몸무게: 99
# 키: 198
# BMI: 25.25
# 결과: 과체중
#
# 이름: 다마
# 몸무게: 58
# 키: 157
# BMI: 23.53
# 결과: 정상체중
#
# 이름: 자차
# 몸무게: 50
# 키: 192
# BMI: 13.56
# 결과: 저체중
#
# 이름: 차카
# 몸무게: 53
# 키: 180
# BMI: 16.36
# 결과: 저체중
#
# 이름: 차파
# 몸무게: 79
# 키: 179
# BMI: 24.66
# 결과: 정상체중
#
# 이름: 다하
# 몸무게: 40
# 키: 177
# BMI: 12.77
# 결과: 저체중
#
# 이름: 사자
# 몸무게: 80
# 키: 157
# BMI: 32.46
# 결과: 과체중
#
# 이름: 마나
# 몸무게: 81
# 키: 146
# BMI: 38.00
# 결과: 과체중
#
# 이름: 타가
# 몸무게: 76
# 키: 181
# BMI: 23.20
# 결과: 정상체중
#
# 이름: 가마
# 몸무게: 73
# 키: 149
# BMI: 32.88
# 결과: 과체중
#
# 이름: 타타
# 몸무게: 70
# 키: 145
# BMI: 33.29
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 96
# 키: 149
# BMI: 43.24
# 결과: 과체중
#
# 이름: 사바
# 몸무게: 77
# 키: 183
# BMI: 22.99
# 결과: 정상체중
#
# 이름: 다하
# 몸무게: 95
# 키: 191
# BMI: 26.04
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 68
# 키: 144
# BMI: 32.79
# 결과: 과체중
#
# 이름: 카바
# 몸무게: 99
# 키: 154
# BMI: 41.74
# 결과: 과체중
#
# 이름: 나바
# 몸무게: 43
# 키: 164
# BMI: 15.99
# 결과: 저체중
#
# 이름: 타마
# 몸무게: 56
# 키: 198
# BMI: 14.28
# 결과: 저체중
#
# 이름: 마다
# 몸무게: 45
# 키: 143
# BMI: 22.01
# 결과: 정상체중
#
# 이름: 자라
# 몸무게: 82
# 키: 183
# BMI: 24.49
# 결과: 정상체중
#
# 이름: 사라
# 몸무게: 99
# 키: 151
# BMI: 43.42
# 결과: 과체중
#
# 이름: 카사
# 몸무게: 66
# 키: 169
# BMI: 23.11
# 결과: 정상체중
#
# 이름: 가차
# 몸무게: 71
# 키: 186
# BMI: 20.52
# 결과: 정상체중
#
# 이름: 가차
# 몸무게: 53
# 키: 177
# BMI: 16.92
# 결과: 저체중
#
# 이름: 차자
# 몸무게: 99
# 키: 146
# BMI: 46.44
# 결과: 과체중
#
# 이름: 다타
# 몸무게: 87
# 키: 152
# BMI: 37.66
# 결과: 과체중
#
# 이름: 라카
# 몸무게: 40
# 키: 155
# BMI: 16.65
# 결과: 저체중
#
# 이름: 파자
# 몸무게: 88
# 키: 187
# BMI: 25.17
# 결과: 과체중
#
# 이름: 라다
# 몸무게: 57
# 키: 160
# BMI: 22.27
# 결과: 정상체중
#
# 이름: 사자
# 몸무게: 71
# 키: 154
# BMI: 29.94
# 결과: 과체중
#
# 이름: 자바
# 몸무게: 79
# 키: 158
# BMI: 31.65
# 결과: 과체중
#
# 이름: 아마
# 몸무게: 49
# 키: 144
# BMI: 23.63
# 결과: 정상체중
#
# 이름: 마하
# 몸무게: 73
# 키: 173
# BMI: 24.39
# 결과: 정상체중
#
# 이름: 사바
# 몸무게: 83
# 키: 196
# BMI: 21.61
# 결과: 정상체중
#
# 이름: 카하
# 몸무게: 85
# 키: 166
# BMI: 30.85
# 결과: 과체중
#
# 이름: 다아
# 몸무게: 55
# 키: 157
# BMI: 22.31
# 결과: 정상체중
#
# 이름: 아다
# 몸무게: 64
# 키: 196
# BMI: 16.66
# 결과: 저체중
#
# 이름: 마자
# 몸무게: 98
# 키: 147
# BMI: 45.35
# 결과: 과체중
#
# 이름: 자카
# 몸무게: 94
# 키: 177
# BMI: 30.00
# 결과: 과체중
#
# 이름: 카가
# 몸무게: 45
# 키: 198
# BMI: 11.48
# 결과: 저체중
#
# 이름: 하아
# 몸무게: 96
# 키: 150
# BMI: 42.67
# 결과: 과체중
#
# 이름: 아아
# 몸무게: 55
# 키: 155
# BMI: 22.89
# 결과: 정상체중
#
# 이름: 카타
# 몸무게: 89
# 키: 147
# BMI: 41.19
# 결과: 과체중
#
# 이름: 라파
# 몸무게: 65
# 키: 156
# BMI: 26.71
# 결과: 과체중
#
# 이름: 나타
# 몸무게: 60
# 키: 165
# BMI: 22.04
# 결과: 정상체중
#
# 이름: 사나
# 몸무게: 89
# 키: 182
# BMI: 26.87
# 결과: 과체중
#
# 이름: 하아
# 몸무게: 63
# 키: 168
# BMI: 22.32
# 결과: 정상체중
#
# 이름: 파차
# 몸무게: 64
# 키: 181
# BMI: 19.54
# 결과: 정상체중
#
# 이름: 자차
# 몸무게: 62
# 키: 179
# BMI: 19.35
# 결과: 정상체중
#
# 이름: 라바
# 몸무게: 68
# 키: 171
# BMI: 23.26
# 결과: 정상체중
#
# 이름: 차타
# 몸무게: 78
# 키: 159
# BMI: 30.85
# 결과: 과체중
#
# 이름: 다하
# 몸무게: 70
# 키: 190
# BMI: 19.39
# 결과: 정상체중
#
# 이름: 카가
# 몸무게: 88
# 키: 147
# BMI: 40.72
# 결과: 과체중
#
# 이름: 다라
# 몸무게: 97
# 키: 178
# BMI: 30.61
# 결과: 과체중
#
# 이름: 바자
# 몸무게: 93
# 키: 185
# BMI: 27.17
# 결과: 과체중
#
# 이름: 라바
# 몸무게: 47
# 키: 185
# BMI: 13.73
# 결과: 저체중
#
# 이름: 아바
# 몸무게: 62
# 키: 141
# BMI: 31.19
# 결과: 과체중
#
# 이름: 나하
# 몸무게: 71
# 키: 184
# BMI: 20.97
# 결과: 정상체중
#
# 이름: 나아
# 몸무게: 99
# 키: 180
# BMI: 30.56
# 결과: 과체중
#
# 이름: 카타
# 몸무게: 92
# 키: 158
# BMI: 36.85
# 결과: 과체중
#
# 이름: 라파
# 몸무게: 90
# 키: 182
# BMI: 27.17
# 결과: 과체중
#
# 이름: 타아
# 몸무게: 65
# 키: 144
# BMI: 31.35
# 결과: 과체중
#
# 이름: 나사
# 몸무게: 44
# 키: 174
# BMI: 14.53
# 결과: 저체중
#
# 이름: 자카
# 몸무게: 53
# 키: 178
# BMI: 16.73
# 결과: 저체중
#
# 이름: 사가
# 몸무게: 69
# 키: 168
# BMI: 24.45
# 결과: 정상체중
#
# 이름: 타바
# 몸무게: 66
# 키: 186
# BMI: 19.08
# 결과: 정상체중
#
# 이름: 카자
# 몸무게: 64
# 키: 179
# BMI: 19.97
# 결과: 정상체중
#
# 이름: 파라
# 몸무게: 99
# 키: 157
# BMI: 40.16
# 결과: 과체중
#
# 이름: 나차
# 몸무게: 73
# 키: 160
# BMI: 28.52
# 결과: 과체중
#
# 이름: 라타
# 몸무게: 73
# 키: 171
# BMI: 24.96
# 결과: 정상체중
#
# 이름: 가가
# 몸무게: 77
# 키: 161
# BMI: 29.71
# 결과: 과체중
#
# 이름: 가하
# 몸무게: 88
# 키: 193
# BMI: 23.62
# 결과: 정상체중
#
# 이름: 가사
# 몸무게: 41
# 키: 174
# BMI: 13.54
# 결과: 저체중
#
# 이름: 가타
# 몸무게: 53
# 키: 198
# BMI: 13.52
# 결과: 저체중
#
# 이름: 차바
# 몸무게: 50
# 키: 144
# BMI: 24.11
# 결과: 정상체중
#
# 이름: 라다
# 몸무게: 97
# 키: 180
# BMI: 29.94
# 결과: 과체중
#
# 이름: 아라
# 몸무게: 86
# 키: 168
# BMI: 30.47
# 결과: 과체중
#
# 이름: 바하
# 몸무게: 71
# 키: 187
# BMI: 20.30
# 결과: 정상체중
#
# 이름: 라차
# 몸무게: 90
# 키: 167
# BMI: 32.27
# 결과: 과체중
#
# 이름: 차다
# 몸무게: 55
# 키: 191
# BMI: 15.08
# 결과: 저체중
#
# 이름: 라타
# 몸무게: 72
# 키: 155
# BMI: 29.97
# 결과: 과체중
#
# 이름: 하하
# 몸무게: 76
# 키: 182
# BMI: 22.94
# 결과: 정상체중
#
# 이름: 라타
# 몸무게: 94
# 키: 140
# BMI: 47.96
# 결과: 과체중
#
# 이름: 카다
# 몸무게: 55
# 키: 167
# BMI: 19.72
# 결과: 정상체중
#
# 이름: 다사
# 몸무게: 86
# 키: 162
# BMI: 32.77
# 결과: 과체중
#
# 이름: 차하
# 몸무게: 85
# 키: 158
# BMI: 34.05
# 결과: 과체중
#
# 이름: 카카
# 몸무게: 68
# 키: 157
# BMI: 27.59
# 결과: 과체중
#
# 이름: 바파
# 몸무게: 68
# 키: 166
# BMI: 24.68
# 결과: 정상체중
#
# 이름: 파차
# 몸무게: 82
# 키: 162
# BMI: 31.25
# 결과: 과체중
#
# 이름: 자마
# 몸무게: 65
# 키: 156
# BMI: 26.71
# 결과: 과체중
#
# 이름: 파다
# 몸무게: 94
# 키: 177
# BMI: 30.00
# 결과: 과체중
#
# 이름: 마가
# 몸무게: 94
# 키: 193
# BMI: 25.24
# 결과: 과체중
#
# 이름: 바가
# 몸무게: 45
# 키: 168
# BMI: 15.94
# 결과: 저체중
#
# 이름: 차다
# 몸무게: 58
# 키: 165
# BMI: 21.30
# 결과: 정상체중
#
# 이름: 아자
# 몸무게: 52
# 키: 196
# BMI: 13.54
# 결과: 저체중
#
# 이름: 사타
# 몸무게: 42
# 키: 158
# BMI: 16.82
# 결과: 저체중
#
# 이름: 자타
# 몸무게: 88
# 키: 179
# BMI: 27.46
# 결과: 과체중
#
# 이름: 하마
# 몸무게: 59
# 키: 155
# BMI: 24.56
# 결과: 정상체중
#
# 이름: 마자
# 몸무게: 78
# 키: 175
# BMI: 25.47
# 결과: 과체중
#
# 이름: 파타
# 몸무게: 78
# 키: 155
# BMI: 32.47
# 결과: 과체중
#
# 이름: 카아
# 몸무게: 72
# 키: 144
# BMI: 34.72
# 결과: 과체중
#
# 이름: 나파
# 몸무게: 85
# 키: 154
# BMI: 35.84
# 결과: 과체중
#
# 이름: 바하
# 몸무게: 80
# 키: 162
# BMI: 30.48
# 결과: 과체중
#
# 이름: 마파
# 몸무게: 47
# 키: 190
# BMI: 13.02
# 결과: 저체중
#
# 이름: 하마
# 몸무게: 87
# 키: 198
# BMI: 22.19
# 결과: 정상체중
#
# 이름: 타파
# 몸무게: 52
# 키: 184
# BMI: 15.36
# 결과: 저체중
#
# 이름: 차라
# 몸무게: 60
# 키: 157
# BMI: 24.34
# 결과: 정상체중
#
# 이름: 아차
# 몸무게: 75
# 키: 140
# BMI: 38.27
# 결과: 과체중
#
# 이름: 다파
# 몸무게: 85
# 키: 198
# BMI: 21.68
# 결과: 정상체중
#
# 이름: 라사
# 몸무게: 46
# 키: 184
# BMI: 13.59
# 결과: 저체중
#
# 이름: 가자
# 몸무게: 57
# 키: 179
# BMI: 17.79
# 결과: 저체중
#
# 이름: 자바
# 몸무게: 51
# 키: 146
# BMI: 23.93
# 결과: 정상체중
#
# 이름: 가파
# 몸무게: 98
# 키: 149
# BMI: 44.14
# 결과: 과체중
#
# 이름: 하아
# 몸무게: 65
# 키: 178
# BMI: 20.52
# 결과: 정상체중
#
# 이름: 라라
# 몸무게: 47
# 키: 197
# BMI: 12.11
# 결과: 저체중
#
# 이름: 카차
# 몸무게: 50
# 키: 155
# BMI: 20.81
# 결과: 정상체중
#
# 이름: 나가
# 몸무게: 43
# 키: 159
# BMI: 17.01
# 결과: 저체중
#
# 이름: 하사
# 몸무게: 54
# 키: 147
# BMI: 24.99
# 결과: 정상체중
#
# 이름: 라마
# 몸무게: 66
# 키: 190
# BMI: 18.28
# 결과: 저체중
#
# 이름: 카바
# 몸무게: 51
# 키: 171
# BMI: 17.44
# 결과: 저체중
#
# 이름: 다파
# 몸무게: 53
# 키: 150
# BMI: 23.56
# 결과: 정상체중
#
# 이름: 자바
# 몸무게: 65
# 키: 177
# BMI: 20.75
# 결과: 정상체중
#
# 이름: 차자
# 몸무게: 42
# 키: 180
# BMI: 12.96
# 결과: 저체중
#
# 이름: 차차
# 몸무게: 40
# 키: 146
# BMI: 18.77
# 결과: 정상체중
#
# 이름: 파마
# 몸무게: 71
# 키: 194
# BMI: 18.86
# 결과: 정상체중
#
# 이름: 타라
# 몸무게: 56
# 키: 193
# BMI: 15.03
# 결과: 저체중
#
# 이름: 파타
# 몸무게: 53
# 키: 174
# BMI: 17.51
# 결과: 저체중
#
# 이름: 다아
# 몸무게: 84
# 키: 144
# BMI: 40.51
# 결과: 과체중
#
# 이름: 라가
# 몸무게: 62
# 키: 194
# BMI: 16.47
# 결과: 저체중
#
# 이름: 바사
# 몸무게: 88
# 키: 149
# BMI: 39.64
# 결과: 과체중
#
# 이름: 바차
# 몸무게: 66
# 키: 194
# BMI: 17.54
# 결과: 저체중
#
# 이름: 바하
# 몸무게: 85
# 키: 194
# BMI: 22.58
# 결과: 정상체중
#
# 이름: 차하
# 몸무게: 82
# 키: 176
# BMI: 26.47
# 결과: 과체중
#
# 이름: 차마
# 몸무게: 64
# 키: 163
# BMI: 24.09
# 결과: 정상체중
#
# 이름: 마타
# 몸무게: 49
# 키: 152
# BMI: 21.21
# 결과: 정상체중
#
# 이름: 하마
# 몸무게: 40
# 키: 193
# BMI: 10.74
# 결과: 저체중
#
# 이름: 가마
# 몸무게: 87
# 키: 167
# BMI: 31.20
# 결과: 과체중
#
# 이름: 나바
# 몸무게: 94
# 키: 154
# BMI: 39.64
# 결과: 과체중
#
# 이름: 다나
# 몸무게: 72
# 키: 156
# BMI: 29.59
# 결과: 과체중
#
# 이름: 마나
# 몸무게: 89
# 키: 180
# BMI: 27.47
# 결과: 과체중
#
# 이름: 카차
# 몸무게: 87
# 키: 189
# BMI: 24.36
# 결과: 정상체중
#
# 이름: 카사
# 몸무게: 55
# 키: 180
# BMI: 16.98
# 결과: 저체중
#
# 이름: 마카
# 몸무게: 77
# 키: 195
# BMI: 20.25
# 결과: 정상체중
#
# 이름: 마나
# 몸무게: 57
# 키: 145
# BMI: 27.11
# 결과: 과체중
#
# 이름: 아다
# 몸무게: 72
# 키: 147
# BMI: 33.32
# 결과: 과체중
#
# 이름: 차가
# 몸무게: 45
# 키: 195
# BMI: 11.83
# 결과: 저체중
#
# 이름: 라가
# 몸무게: 68
# 키: 199
# BMI: 17.17
# 결과: 저체중
#
# 이름: 바파
# 몸무게: 45
# 키: 168
# BMI: 15.94
# 결과: 저체중
#
# 이름: 마나
# 몸무게: 64
# 키: 160
# BMI: 25.00
# 결과: 정상체중
#
# 이름: 카라
# 몸무게: 79
# 키: 171
# BMI: 27.02
# 결과: 과체중
#
# 이름: 마카
# 몸무게: 72
# 키: 169
# BMI: 25.21
# 결과: 과체중
#
# 이름: 타카
# 몸무게: 46
# 키: 153
# BMI: 19.65
# 결과: 정상체중
#
# 이름: 다아
# 몸무게: 53
# 키: 148
# BMI: 24.20
# 결과: 정상체중
#
# 이름: 사파
# 몸무게: 74
# 키: 161
# BMI: 28.55
# 결과: 과체중
#
# 이름: 바카
# 몸무게: 50
# 키: 185
# BMI: 14.61
# 결과: 저체중
#
# 이름: 나바
# 몸무게: 66
# 키: 142
# BMI: 32.73
# 결과: 과체중
#
# 이름: 사자
# 몸무게: 86
# 키: 143
# BMI: 42.06
# 결과: 과체중
#
# 이름: 사파
# 몸무게: 54
# 키: 156
# BMI: 22.19
# 결과: 정상체중
#
# 이름: 사라
# 몸무게: 95
# 키: 167
# BMI: 34.06
# 결과: 과체중
#
# 이름: 카하
# 몸무게: 66
# 키: 170
# BMI: 22.84
# 결과: 정상체중
#
# 이름: 사바
# 몸무게: 98
# 키: 195
# BMI: 25.77
# 결과: 과체중
#
# 이름: 아자
# 몸무게: 65
# 키: 141
# BMI: 32.69
# 결과: 과체중
#
# 이름: 바마
# 몸무게: 48
# 키: 158
# BMI: 19.23
# 결과: 정상체중
#
# 이름: 나아
# 몸무게: 44
# 키: 189
# BMI: 12.32
# 결과: 저체중
#
# 이름: 마마
# 몸무게: 55
# 키: 170
# BMI: 19.03
# 결과: 정상체중
#
# 이름: 카타
# 몸무게: 41
# 키: 163
# BMI: 15.43
# 결과: 저체중
#
# 이름: 파라
# 몸무게: 48
# 키: 165
# BMI: 17.63
# 결과: 저체중
#
# 이름: 하나
# 몸무게: 50
# 키: 161
# BMI: 19.29
# 결과: 정상체중
#
# 이름: 마차
# 몸무게: 91
# 키: 148
# BMI: 41.54
# 결과: 과체중
#
# 이름: 하사
# 몸무게: 95
# 키: 152
# BMI: 41.12
# 결과: 과체중
#
# 이름: 다마
# 몸무게: 45
# 키: 146
# BMI: 21.11
# 결과: 정상체중
#
# 이름: 하자
# 몸무게: 98
# 키: 173
# BMI: 32.74
# 결과: 과체중
#
# 이름: 아자
# 몸무게: 55
# 키: 140
# BMI: 28.06
# 결과: 과체중
#
# 이름: 자아
# 몸무게: 60
# 키: 166
# BMI: 21.77
# 결과: 정상체중
#
# 이름: 가나
# 몸무게: 65
# 키: 161
# BMI: 25.08
# 결과: 과체중
#
# 이름: 바다
# 몸무게: 96
# 키: 144
# BMI: 46.30
# 결과: 과체중
#
# 이름: 가다
# 몸무게: 94
# 키: 187
# BMI: 26.88
# 결과: 과체중
#
# 이름: 자다
# 몸무게: 41
# 키: 167
# BMI: 14.70
# 결과: 저체중
#
# 이름: 하라
# 몸무게: 78
# 키: 188
# BMI: 22.07
# 결과: 정상체중
#
# 이름: 다차
# 몸무게: 56
# 키: 161
# BMI: 21.60
# 결과: 정상체중
#
# 이름: 라마
# 몸무게: 56
# 키: 190
# BMI: 15.51
# 결과: 저체중
#
# 이름: 바자
# 몸무게: 47
# 키: 156
# BMI: 19.31
# 결과: 정상체중
#
# 이름: 자하
# 몸무게: 68
# 키: 168
# BMI: 24.09
# 결과: 정상체중
#
# 이름: 차가
# 몸무게: 41
# 키: 192
# BMI: 11.12
# 결과: 저체중
#
# 이름: 아가
# 몸무게: 91
# 키: 172
# BMI: 30.76
# 결과: 과체중
#
# 이름: 라하
# 몸무게: 93
# 키: 181
# BMI: 28.39
# 결과: 과체중
#
# 이름: 자자
# 몸무게: 79
# 키: 175
# BMI: 25.80
# 결과: 과체중
#
# 이름: 타타
# 몸무게: 51
# 키: 154
# BMI: 21.50
# 결과: 정상체중
#
# 이름: 사사
# 몸무게: 83
# 키: 146
# BMI: 38.94
# 결과: 과체중
#
# 이름: 바가
# 몸무게: 81
# 키: 180
# BMI: 25.00
# 결과: 과체중
#
# 이름: 아가
# 몸무게: 78
# 키: 160
# BMI: 30.47
# 결과: 과체중
#
# 이름: 사차
# 몸무게: 91
# 키: 144
# BMI: 43.89
# 결과: 과체중
#
# 이름: 가다
# 몸무게: 72
# 키: 173
# BMI: 24.06
# 결과: 정상체중
#
# 이름: 카다
# 몸무게: 78
# 키: 159
# BMI: 30.85
# 결과: 과체중
#
# 이름: 나마
# 몸무게: 85
# 키: 147
# BMI: 39.34
# 결과: 과체중
#
# 이름: 마가
# 몸무게: 96
# 키: 180
# BMI: 29.63
# 결과: 과체중
#
# 이름: 마자
# 몸무게: 57
# 키: 171
# BMI: 19.49
# 결과: 정상체중
#
# 이름: 아하
# 몸무게: 95
# 키: 179
# BMI: 29.65
# 결과: 과체중
#
# 이름: 자하
# 몸무게: 63
# 키: 169
# BMI: 22.06
# 결과: 정상체중
#
# 이름: 다가
# 몸무게: 52
# 키: 198
# BMI: 13.26
# 결과: 저체중
#
# 이름: 하카
# 몸무게: 94
# 키: 171
# BMI: 32.15
# 결과: 과체중
#
# 이름: 차가
# 몸무게: 73
# 키: 162
# BMI: 27.82
# 결과: 과체중
#
# 이름: 카마
# 몸무게: 68
# 키: 146
# BMI: 31.90
# 결과: 과체중
#
# 이름: 나사
# 몸무게: 59
# 키: 185
# BMI: 17.24
# 결과: 저체중
#
# 이름: 파나
# 몸무게: 90
# 키: 142
# BMI: 44.63
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 97
# 키: 145
# BMI: 46.14
# 결과: 과체중
#
# 이름: 아타
# 몸무게: 90
# 키: 187
# BMI: 25.74
# 결과: 과체중
#
# 이름: 사라
# 몸무게: 52
# 키: 179
# BMI: 16.23
# 결과: 저체중
#
# 이름: 자아
# 몸무게: 52
# 키: 140
# BMI: 26.53
# 결과: 과체중
#
# 이름: 라자
# 몸무게: 98
# 키: 151
# BMI: 42.98
# 결과: 과체중
#
# 이름: 자아
# 몸무게: 86
# 키: 188
# BMI: 24.33
# 결과: 정상체중
#
# 이름: 바마
# 몸무게: 97
# 키: 187
# BMI: 27.74
# 결과: 과체중
#
# 이름: 라바
# 몸무게: 90
# 키: 176
# BMI: 29.05
# 결과: 과체중
#
# 이름: 바파
# 몸무게: 53
# 키: 165
# BMI: 19.47
# 결과: 정상체중
#
# 이름: 라타
# 몸무게: 63
# 키: 173
# BMI: 21.05
# 결과: 정상체중
#
# 이름: 다나
# 몸무게: 83
# 키: 146
# BMI: 38.94
# 결과: 과체중
#
# 이름: 하자
# 몸무게: 70
# 키: 161
# BMI: 27.01
# 결과: 과체중
#
# 이름: 차아
# 몸무게: 60
# 키: 172
# BMI: 20.28
# 결과: 정상체중
#
# 이름: 가타
# 몸무게: 72
# 키: 150
# BMI: 32.00
# 결과: 과체중
#
# 이름: 바마
# 몸무게: 92
# 키: 168
# BMI: 32.60
# 결과: 과체중
#
# 이름: 바카
# 몸무게: 82
# 키: 145
# BMI: 39.00
# 결과: 과체중
#
# 이름: 타다
# 몸무게: 98
# 키: 192
# BMI: 26.58
# 결과: 과체중
#
# 이름: 사자
# 몸무게: 49
# 키: 171
# BMI: 16.76
# 결과: 저체중
#
# 이름: 아사
# 몸무게: 45
# 키: 198
# BMI: 11.48
# 결과: 저체중
#
# 이름: 나자
# 몸무게: 64
# 키: 154
# BMI: 26.99
# 결과: 과체중
#
# 이름: 가차
# 몸무게: 73
# 키: 150
# BMI: 32.44
# 결과: 과체중
#
# 이름: 마가
# 몸무게: 50
# 키: 154
# BMI: 21.08
# 결과: 정상체중
#
# 이름: 아마
# 몸무게: 75
# 키: 153
# BMI: 32.04
# 결과: 과체중
#
# 이름: 자타
# 몸무게: 67
# 키: 186
# BMI: 19.37
# 결과: 정상체중
#
# 이름: 하사
# 몸무게: 88
# 키: 178
# BMI: 27.77
# 결과: 과체중
#
# 이름: 파나
# 몸무게: 95
# 키: 197
# BMI: 24.48
# 결과: 정상체중
#
# 이름: 사라
# 몸무게: 88
# 키: 199
# BMI: 22.22
# 결과: 정상체중
#
# 이름: 가카
# 몸무게: 40
# 키: 169
# BMI: 14.01
# 결과: 저체중
#
# 이름: 사사
# 몸무게: 88
# 키: 196
# BMI: 22.91
# 결과: 정상체중
#
# 이름: 사라
# 몸무게: 59
# 키: 188
# BMI: 16.69
# 결과: 저체중
#
# 이름: 바차
# 몸무게: 42
# 키: 151
# BMI: 18.42
# 결과: 저체중
#
# 이름: 마사
# 몸무게: 57
# 키: 187
# BMI: 16.30
# 결과: 저체중
#
# 이름: 라나
# 몸무게: 87
# 키: 143
# BMI: 42.54
# 결과: 과체중
#
# 이름: 라다
# 몸무게: 40
# 키: 170
# BMI: 13.84
# 결과: 저체중
#
# 이름: 타가
# 몸무게: 57
# 키: 163
# BMI: 21.45
# 결과: 정상체중
#
# 이름: 타자
# 몸무게: 91
# 키: 189
# BMI: 25.48
# 결과: 과체중
#
# 이름: 하카
# 몸무게: 86
# 키: 179
# BMI: 26.84
# 결과: 과체중
#
# 이름: 카다
# 몸무게: 67
# 키: 171
# BMI: 22.91
# 결과: 정상체중
#
# 이름: 사바
# 몸무게: 40
# 키: 169
# BMI: 14.01
# 결과: 저체중
#
# 이름: 가바
# 몸무게: 91
# 키: 159
# BMI: 36.00
# 결과: 과체중
#
# 이름: 바다
# 몸무게: 88
# 키: 190
# BMI: 24.38
# 결과: 정상체중
#
# 이름: 자자
# 몸무게: 63
# 키: 165
# BMI: 23.14
# 결과: 정상체중
#
# 이름: 아마
# 몸무게: 74
# 키: 170
# BMI: 25.61
# 결과: 과체중
#
# 이름: 나바
# 몸무게: 73
# 키: 199
# BMI: 18.43
# 결과: 저체중
#
# 이름: 카가
# 몸무게: 49
# 키: 196
# BMI: 12.76
# 결과: 저체중
#
# 이름: 나바
# 몸무게: 87
# 키: 165
# BMI: 31.96
# 결과: 과체중
#
# 이름: 가차
# 몸무게: 79
# 키: 140
# BMI: 40.31
# 결과: 과체중
#
# 이름: 카마
# 몸무게: 43
# 키: 153
# BMI: 18.37
# 결과: 저체중
#
# 이름: 사가
# 몸무게: 99
# 키: 177
# BMI: 31.60
# 결과: 과체중
#
# 이름: 다마
# 몸무게: 77
# 키: 151
# BMI: 33.77
# 결과: 과체중
#
# 이름: 가하
# 몸무게: 73
# 키: 179
# BMI: 22.78
# 결과: 정상체중
#
# 이름: 자다
# 몸무게: 44
# 키: 187
# BMI: 12.58
# 결과: 저체중
#
# 이름: 바바
# 몸무게: 44
# 키: 176
# BMI: 14.20
# 결과: 저체중
#
# 이름: 바사
# 몸무게: 80
# 키: 199
# BMI: 20.20
# 결과: 정상체중
#
# 이름: 다가
# 몸무게: 74
# 키: 199
# BMI: 18.69
# 결과: 정상체중
#
# 이름: 자타
# 몸무게: 47
# 키: 162
# BMI: 17.91
# 결과: 저체중
#
# 이름: 파바
# 몸무게: 82
# 키: 169
# BMI: 28.71
# 결과: 과체중
#
# 이름: 자사
# 몸무게: 42
# 키: 146
# BMI: 19.70
# 결과: 정상체중
#
# 이름: 라카
# 몸무게: 74
# 키: 184
# BMI: 21.86
# 결과: 정상체중
#
# 이름: 타마
# 몸무게: 95
# 키: 162
# BMI: 36.20
# 결과: 과체중
#
# 이름: 하나
# 몸무게: 49
# 키: 190
# BMI: 13.57
# 결과: 저체중
#
# 이름: 파자
# 몸무게: 44
# 키: 141
# BMI: 22.13
# 결과: 정상체중
#
# 이름: 바나
# 몸무게: 86
# 키: 155
# BMI: 35.80
# 결과: 과체중
#
# 이름: 사사
# 몸무게: 68
# 키: 182
# BMI: 20.53
# 결과: 정상체중
#
# 이름: 나자
# 몸무게: 92
# 키: 187
# BMI: 26.31
# 결과: 과체중
#
# 이름: 사파
# 몸무게: 76
# 키: 169
# BMI: 26.61
# 결과: 과체중
#
# 이름: 하사
# 몸무게: 56
# 키: 185
# BMI: 16.36
# 결과: 저체중
#
# 이름: 아차
# 몸무게: 65
# 키: 152
# BMI: 28.13
# 결과: 과체중
#
# 이름: 파타
# 몸무게: 72
# 키: 166
# BMI: 26.13
# 결과: 과체중
#
# 이름: 아사
# 몸무게: 72
# 키: 156
# BMI: 29.59
# 결과: 과체중
#
# 이름: 자나
# 몸무게: 45
# 키: 142
# BMI: 22.32
# 결과: 정상체중
#
# 이름: 하라
# 몸무게: 49
# 키: 157
# BMI: 19.88
# 결과: 정상체중
#
# 이름: 바마
# 몸무게: 79
# 키: 178
# BMI: 24.93
# 결과: 정상체중
#
# 이름: 하파
# 몸무게: 49
# 키: 171
# BMI: 16.76
# 결과: 저체중
#
# 이름: 라카
# 몸무게: 47
# 키: 173
# BMI: 15.70
# 결과: 저체중
#
# 이름: 파아
# 몸무게: 92
# 키: 194
# BMI: 24.44
# 결과: 정상체중
#
# 이름: 가하
# 몸무게: 87
# 키: 144
# BMI: 41.96
# 결과: 과체중
#
# 이름: 아자
# 몸무게: 66
# 키: 191
# BMI: 18.09
# 결과: 저체중
#
# 이름: 차자
# 몸무게: 80
# 키: 144
# BMI: 38.58
# 결과: 과체중
#
# 이름: 파카
# 몸무게: 66
# 키: 183
# BMI: 19.71
# 결과: 정상체중
#
# 이름: 다자
# 몸무게: 42
# 키: 196
# BMI: 10.93
# 결과: 저체중
#
# 이름: 라사
# 몸무게: 57
# 키: 142
# BMI: 28.27
# 결과: 과체중
#
# 이름: 나사
# 몸무게: 76
# 키: 162
# BMI: 28.96
# 결과: 과체중
#
# 이름: 파하
# 몸무게: 43
# 키: 152
# BMI: 18.61
# 결과: 정상체중
#
# 이름: 차다
# 몸무게: 84
# 키: 144
# BMI: 40.51
# 결과: 과체중
#
# 이름: 가나
# 몸무게: 81
# 키: 166
# BMI: 29.39
# 결과: 과체중
#
# 이름: 다바
# 몸무게: 46
# 키: 177
# BMI: 14.68
# 결과: 저체중
#
# 이름: 바하
# 몸무게: 53
# 키: 171
# BMI: 18.13
# 결과: 저체중
#
# 이름: 라카
# 몸무게: 98
# 키: 176
# BMI: 31.64
# 결과: 과체중
#
# 이름: 차바
# 몸무게: 40
# 키: 163
# BMI: 15.06
# 결과: 저체중
#
# 이름: 라라
# 몸무게: 82
# 키: 160
# BMI: 32.03
# 결과: 과체중
#
# 이름: 나바
# 몸무게: 43
# 키: 199
# BMI: 10.86
# 결과: 저체중
#
# 이름: 자라
# 몸무게: 89
# 키: 181
# BMI: 27.17
# 결과: 과체중
#
# 이름: 나다
# 몸무게: 86
# 키: 187
# BMI: 24.59
# 결과: 정상체중
#
# 이름: 차하
# 몸무게: 63
# 키: 149
# BMI: 28.38
# 결과: 과체중
#
# 이름: 카나
# 몸무게: 58
# 키: 171
# BMI: 19.84
# 결과: 정상체중
#
# 이름: 아라
# 몸무게: 74
# 키: 184
# BMI: 21.86
# 결과: 정상체중
#
# 이름: 바가
# 몸무게: 76
# 키: 162
# BMI: 28.96
# 결과: 과체중
#
# 이름: 다마
# 몸무게: 86
# 키: 182
# BMI: 25.96
# 결과: 과체중
#
# 이름: 다다
# 몸무게: 57
# 키: 195
# BMI: 14.99
# 결과: 저체중
#
# 이름: 타다
# 몸무게: 59
# 키: 163
# BMI: 22.21
# 결과: 정상체중
#
# 이름: 사다
# 몸무게: 59
# 키: 198
# BMI: 15.05
# 결과: 저체중
#
# 이름: 타가
# 몸무게: 78
# 키: 176
# BMI: 25.18
# 결과: 과체중
#
# 이름: 라차
# 몸무게: 83
# 키: 172
# BMI: 28.06
# 결과: 과체중
#
# 이름: 나라
# 몸무게: 82
# 키: 146
# BMI: 38.47
# 결과: 과체중
#
# 이름: 나사
# 몸무게: 64
# 키: 143
# BMI: 31.30
# 결과: 과체중
#
# 이름: 타자
# 몸무게: 58
# 키: 185
# BMI: 16.95
# 결과: 저체중
#
# 이름: 하마
# 몸무게: 65
# 키: 149
# BMI: 29.28
# 결과: 과체중
#
# 이름: 라바
# 몸무게: 73
# 키: 161
# BMI: 28.16
# 결과: 과체중
#
# 이름: 다자
# 몸무게: 58
# 키: 170
# BMI: 20.07
# 결과: 정상체중
#
# 이름: 다사
# 몸무게: 67
# 키: 176
# BMI: 21.63
# 결과: 정상체중
#
# 이름: 가가
# 몸무게: 54
# 키: 187
# BMI: 15.44
# 결과: 저체중
#
# 이름: 아가
# 몸무게: 84
# 키: 155
# BMI: 34.96
# 결과: 과체중
#
# 이름: 차카
# 몸무게: 67
# 키: 177
# BMI: 21.39
# 결과: 정상체중
#
# 이름: 자나
# 몸무게: 46
# 키: 149
# BMI: 20.72
# 결과: 정상체중
#
# 이름: 하카
# 몸무게: 83
# 키: 188
# BMI: 23.48
# 결과: 정상체중
#
# 이름: 자다
# 몸무게: 53
# 키: 184
# BMI: 15.65
# 결과: 저체중
#
# 이름: 타파
# 몸무게: 90
# 키: 148
# BMI: 41.09
# 결과: 과체중
#
# 이름: 사마
# 몸무게: 83
# 키: 184
# BMI: 24.52
# 결과: 정상체중
#
# 이름: 나하
# 몸무게: 73
# 키: 142
# BMI: 36.20
# 결과: 과체중
#
# 이름: 라라
# 몸무게: 73
# 키: 197
# BMI: 18.81
# 결과: 정상체중
#
# 이름: 파카
# 몸무게: 64
# 키: 148
# BMI: 29.22
# 결과: 과체중
#
# 이름: 바자
# 몸무게: 75
# 키: 154
# BMI: 31.62
# 결과: 과체중
#
# 이름: 마자
# 몸무게: 89
# 키: 144
# BMI: 42.92
# 결과: 과체중
#
# 이름: 파카
# 몸무게: 46
# 키: 160
# BMI: 17.97
# 결과: 저체중
#
# 이름: 나마
# 몸무게: 94
# 키: 169
# BMI: 32.91
# 결과: 과체중
#
# 이름: 나바
# 몸무게: 92
# 키: 191
# BMI: 25.22
# 결과: 과체중
#
# 이름: 사바
# 몸무게: 49
# 키: 175
# BMI: 16.00
# 결과: 저체중
#
# 이름: 파바
# 몸무게: 46
# 키: 147
# BMI: 21.29
# 결과: 정상체중
#
# 이름: 아다
# 몸무게: 43
# 키: 179
# BMI: 13.42
# 결과: 저체중
#
# 이름: 나타
# 몸무게: 80
# 키: 176
# BMI: 25.83
# 결과: 과체중
#
# 이름: 차나
# 몸무게: 99
# 키: 154
# BMI: 41.74
# 결과: 과체중
#
# 이름: 아바
# 몸무게: 70
# 키: 181
# BMI: 21.37
# 결과: 정상체중
#
# 이름: 사하
# 몸무게: 91
# 키: 157
# BMI: 36.92
# 결과: 과체중
#
# 이름: 마하
# 몸무게: 79
# 키: 193
# BMI: 21.21
# 결과: 정상체중
#
# 이름: 다아
# 몸무게: 67
# 키: 158
# BMI: 26.84
# 결과: 과체중
#
# 이름: 자카
# 몸무게: 83
# 키: 184
# BMI: 24.52
# 결과: 정상체중
#
# 이름: 라마
# 몸무게: 61
# 키: 185
# BMI: 17.82
# 결과: 저체중
#
# 이름: 차사
# 몸무게: 63
# 키: 180
# BMI: 19.44
# 결과: 정상체중
#
# 이름: 하자
# 몸무게: 57
# 키: 175
# BMI: 18.61
# 결과: 정상체중
#
# 이름: 아나
# 몸무게: 89
# 키: 177
# BMI: 28.41
# 결과: 과체중
#
# 이름: 하차
# 몸무게: 48
# 키: 188
# BMI: 13.58
# 결과: 저체중
#
# 이름: 사하
# 몸무게: 78
# 키: 155
# BMI: 32.47
# 결과: 과체중
#
# 이름: 사타
# 몸무게: 78
# 키: 156
# BMI: 32.05
# 결과: 과체중
#
# 이름: 아바
# 몸무게: 67
# 키: 188
# BMI: 18.96
# 결과: 정상체중
#
# 이름: 라라
# 몸무게: 96
# 키: 190
# BMI: 26.59
# 결과: 과체중
#
# 이름: 차하
# 몸무게: 78
# 키: 199
# BMI: 19.70
# 결과: 정상체중
#
# 이름: 자가
# 몸무게: 78
# 키: 180
# BMI: 24.07
# 결과: 정상체중
#
# 이름: 바아
# 몸무게: 55
# 키: 143
# BMI: 26.90
# 결과: 과체중
#
# 이름: 하바
# 몸무게: 48
# 키: 183
# BMI: 14.33
# 결과: 저체중
#
# 이름: 자마
# 몸무게: 83
# 키: 160
# BMI: 32.42
# 결과: 과체중
#
# 이름: 나타
# 몸무게: 85
# 키: 164
# BMI: 31.60
# 결과: 과체중
#
# 이름: 타다
# 몸무게: 94
# 키: 186
# BMI: 27.17
# 결과: 과체중
#
# 이름: 사나
# 몸무게: 77
# 키: 165
# BMI: 28.28
# 결과: 과체중
#
# 이름: 라타
# 몸무게: 68
# 키: 165
# BMI: 24.98
# 결과: 정상체중
#
# 이름: 다나
# 몸무게: 96
# 키: 140
# BMI: 48.98
# 결과: 과체중
#
# 이름: 아차
# 몸무게: 51
# 키: 193
# BMI: 13.69
# 결과: 저체중
#
# 이름: 하카
# 몸무게: 61
# 키: 153
# BMI: 26.06
# 결과: 과체중
#
# 이름: 하파
# 몸무게: 88
# 키: 194
# BMI: 23.38
# 결과: 정상체중
#
# 이름: 라아
# 몸무게: 53
# 키: 169
# BMI: 18.56
# 결과: 정상체중
#
# 이름: 바사
# 몸무게: 58
# 키: 157
# BMI: 23.53
# 결과: 정상체중
#
# 이름: 차아
# 몸무게: 67
# 키: 143
# BMI: 32.76
# 결과: 과체중
#
# 이름: 마타
# 몸무게: 71
# 키: 180
# BMI: 21.91
# 결과: 정상체중
#
# 이름: 다파
# 몸무게: 56
# 키: 150
# BMI: 24.89
# 결과: 정상체중
#
# 이름: 카파
# 몸무게: 50
# 키: 161
# BMI: 19.29
# 결과: 정상체중
#
# 이름: 아파
# 몸무게: 91
# 키: 193
# BMI: 24.43
# 결과: 정상체중
#
# 이름: 가파
# 몸무게: 66
# 키: 182
# BMI: 19.93
# 결과: 정상체중
#
# 이름: 아차
# 몸무게: 68
# 키: 186
# BMI: 19.66
# 결과: 정상체중
#
# 이름: 나자
# 몸무게: 87
# 키: 180
# BMI: 26.85
# 결과: 과체중
#
# 이름: 자자
# 몸무게: 71
# 키: 179
# BMI: 22.16
# 결과: 정상체중
#
# 이름: 파파
# 몸무게: 84
# 키: 143
# BMI: 41.08
# 결과: 과체중
#
# 이름: 카마
# 몸무게: 78
# 키: 160
# BMI: 30.47
# 결과: 과체중
#
# 이름: 라차
# 몸무게: 54
# 키: 192
# BMI: 14.65
# 결과: 저체중
#
# 이름: 라라
# 몸무게: 61
# 키: 198
# BMI: 15.56
# 결과: 저체중
#
# 이름: 사카
# 몸무게: 97
# 키: 193
# BMI: 26.04
# 결과: 과체중
#
# 이름: 바라
# 몸무게: 86
# 키: 140
# BMI: 43.88
# 결과: 과체중
#
# 이름: 바다
# 몸무게: 95
# 키: 141
# BMI: 47.78
# 결과: 과체중
#
# 이름: 나카
# 몸무게: 40
# 키: 147
# BMI: 18.51
# 결과: 정상체중
#
# 이름: 가가
# 몸무게: 80
# 키: 194
# BMI: 21.26
# 결과: 정상체중
#
# 이름: 타가
# 몸무게: 62
# 키: 162
# BMI: 23.62
# 결과: 정상체중
#
# 이름: 가아
# 몸무게: 76
# 키: 174
# BMI: 25.10
# 결과: 과체중
#
# 이름: 가아
# 몸무게: 94
# 키: 159
# BMI: 37.18
# 결과: 과체중
#
# 이름: 타아
# 몸무게: 85
# 키: 169
# BMI: 29.76
# 결과: 과체중
#
# 이름: 다아
# 몸무게: 63
# 키: 141
# BMI: 31.69
# 결과: 과체중
#
# 이름: 가타
# 몸무게: 44
# 키: 170
# BMI: 15.22
# 결과: 저체중
#
# 이름: 다다
# 몸무게: 89
# 키: 157
# BMI: 36.11
# 결과: 과체중
#
# 이름: 자차
# 몸무게: 64
# 키: 145
# BMI: 30.44
# 결과: 과체중
#
# 이름: 바마
# 몸무게: 86
# 키: 190
# BMI: 23.82
# 결과: 정상체중
#
# 이름: 나바
# 몸무게: 66
# 키: 144
# BMI: 31.83
# 결과: 과체중
#
# 이름: 사마
# 몸무게: 55
# 키: 179
# BMI: 17.17
# 결과: 저체중
#
# 이름: 바카
# 몸무게: 83
# 키: 187
# BMI: 23.74
# 결과: 정상체중
#
# 이름: 하파
# 몸무게: 88
# 키: 184
# BMI: 25.99
# 결과: 과체중
#
# 이름: 가라
# 몸무게: 47
# 키: 166
# BMI: 17.06
# 결과: 저체중
#
# 이름: 사나
# 몸무게: 42
# 키: 155
# BMI: 17.48
# 결과: 저체중
#
# 이름: 가마
# 몸무게: 70
# 키: 195
# BMI: 18.41
# 결과: 저체중
#
# 이름: 파타
# 몸무게: 72
# 키: 192
# BMI: 19.53
# 결과: 정상체중
#
# 이름: 하나
# 몸무게: 47
# 키: 149
# BMI: 21.17
# 결과: 정상체중
#
# 이름: 카사
# 몸무게: 48
# 키: 178
# BMI: 15.15
# 결과: 저체중
#
# 이름: 차아
# 몸무게: 49
# 키: 191
# BMI: 13.43
# 결과: 저체중
#
# 이름: 자아
# 몸무게: 95
# 키: 160
# BMI: 37.11
# 결과: 과체중
#
# 이름: 카사
# 몸무게: 56
# 키: 140
# BMI: 28.57
# 결과: 과체중
#
# 이름: 나하
# 몸무게: 42
# 키: 191
# BMI: 11.51
# 결과: 저체중
#
# 이름: 파하
# 몸무게: 57
# 키: 180
# BMI: 17.59
# 결과: 저체중
#
# 이름: 바하
# 몸무게: 70
# 키: 178
# BMI: 22.09
# 결과: 정상체중
#
# 이름: 파하
# 몸무게: 94
# 키: 148
# BMI: 42.91
# 결과: 과체중
#
# 이름: 차하
# 몸무게: 98
# 키: 146
# BMI: 45.97
# 결과: 과체중
#
# 이름: 파바
# 몸무게: 45
# 키: 149
# BMI: 20.27
# 결과: 정상체중
#
# 이름: 마바
# 몸무게: 90
# 키: 187
# BMI: 25.74
# 결과: 과체중
#
# 이름: 파하
# 몸무게: 41
# 키: 167
# BMI: 14.70
# 결과: 저체중
#
# 이름: 타사
# 몸무게: 88
# 키: 176
# BMI: 28.41
# 결과: 과체중
#
# 이름: 아마
# 몸무게: 99
# 키: 172
# BMI: 33.46
# 결과: 과체중
#
# 이름: 마라
# 몸무게: 57
# 키: 159
# BMI: 22.55
# 결과: 정상체중
#
# 이름: 아카
# 몸무게: 69
# 키: 162
# BMI: 26.29
# 결과: 과체중
#
# 이름: 마자
# 몸무게: 93
# 키: 164
# BMI: 34.58
# 결과: 과체중
#
# 이름: 사나
# 몸무게: 96
# 키: 140
# BMI: 48.98
# 결과: 과체중
#
# 이름: 아가
# 몸무게: 77
# 키: 179
# BMI: 24.03
# 결과: 정상체중
#
# 이름: 타파
# 몸무게: 54
# 키: 145
# BMI: 25.68
# 결과: 과체중
#
# 이름: 바라
# 몸무게: 96
# 키: 174
# BMI: 31.71
# 결과: 과체중
#
# 이름: 나다
# 몸무게: 51
# 키: 162
# BMI: 19.43
# 결과: 정상체중
#
# 이름: 자나
# 몸무게: 90
# 키: 184
# BMI: 26.58
# 결과: 과체중
#
# 이름: 하자
# 몸무게: 88
# 키: 162
# BMI: 33.53
# 결과: 과체중
#
# 이름: 사아
# 몸무게: 54
# 키: 196
# BMI: 14.06
# 결과: 저체중
#
# 이름: 사아
# 몸무게: 62
# 키: 175
# BMI: 20.24
# 결과: 정상체중
#
# 이름: 타타
# 몸무게: 75
# 키: 193
# BMI: 20.13
# 결과: 정상체중
#
# 이름: 파가
# 몸무게: 73
# 키: 189
# BMI: 20.44
# 결과: 정상체중
#
# 이름: 하바
# 몸무게: 62
# 키: 148
# BMI: 28.31
# 결과: 과체중
#
# 이름: 자라
# 몸무게: 70
# 키: 198
# BMI: 17.86
# 결과: 저체중
#
# 이름: 마나
# 몸무게: 53
# 키: 197
# BMI: 13.66
# 결과: 저체중
#
# 이름: 하라
# 몸무게: 81
# 키: 194
# BMI: 21.52
# 결과: 정상체중
#
# 이름: 바타
# 몸무게: 46
# 키: 173
# BMI: 15.37
# 결과: 저체중
#
# 이름: 다바
# 몸무게: 41
# 키: 154
# BMI: 17.29
# 결과: 저체중
#
# 이름: 파바
# 몸무게: 64
# 키: 188
# BMI: 18.11
# 결과: 저체중
#
# 이름: 아가
# 몸무게: 97
# 키: 187
# BMI: 27.74
# 결과: 과체중
#
# 이름: 하차
# 몸무게: 83
# 키: 150
# BMI: 36.89
# 결과: 과체중
#
# 이름: 차카
# 몸무게: 79
# 키: 152
# BMI: 34.19
# 결과: 과체중
#
# 이름: 카파
# 몸무게: 59
# 키: 163
# BMI: 22.21
# 결과: 정상체중
#
# 이름: 라아
# 몸무게: 62
# 키: 143
# BMI: 30.32
# 결과: 과체중
#
# 이름: 바아
# 몸무게: 85
# 키: 170
# BMI: 29.41
# 결과: 과체중
#
# 이름: 나사
# 몸무게: 79
# 키: 142
# BMI: 39.18
# 결과: 과체중
#
# 이름: 라파
# 몸무게: 69
# 키: 175
# BMI: 22.53
# 결과: 정상체중
#
# 이름: 차사
# 몸무게: 50
# 키: 177
# BMI: 15.96
# 결과: 저체중
#
# 이름: 아바
# 몸무게: 47
# 키: 172
# BMI: 15.89
# 결과: 저체중
#
# 이름: 바자
# 몸무게: 92
# 키: 158
# BMI: 36.85
# 결과: 과체중
#
# 이름: 아바
# 몸무게: 91
# 키: 142
# BMI: 45.13
# 결과: 과체중
#
# 이름: 다마
# 몸무게: 67
# 키: 176
# BMI: 21.63
# 결과: 정상체중
#
# 이름: 마바
# 몸무게: 70
# 키: 165
# BMI: 25.71
# 결과: 과체중
#
# 이름: 하바
# 몸무게: 56
# 키: 150
# BMI: 24.89
# 결과: 정상체중
#
# 이름: 바카
# 몸무게: 94
# 키: 145
# BMI: 44.71
# 결과: 과체중
#
# 이름: 카하
# 몸무게: 46
# 키: 147
# BMI: 21.29
# 결과: 정상체중
#
# 이름: 자사
# 몸무게: 92
# 키: 146
# BMI: 43.16
# 결과: 과체중
#
# 이름: 다나
# 몸무게: 59
# 키: 177
# BMI: 18.83
# 결과: 정상체중
#
# 이름: 바나
# 몸무게: 61
# 키: 173
# BMI: 20.38
# 결과: 정상체중
#
# 이름: 사마
# 몸무게: 64
# 키: 197
# BMI: 16.49
# 결과: 저체중
#
# 이름: 카자
# 몸무게: 74
# 키: 168
# BMI: 26.22
# 결과: 과체중
#
# 이름: 사라
# 몸무게: 83
# 키: 169
# BMI: 29.06
# 결과: 과체중
#
# 이름: 카가
# 몸무게: 91
# 키: 162
# BMI: 34.67
# 결과: 과체중
#
# 이름: 하다
# 몸무게: 92
# 키: 191
# BMI: 25.22
# 결과: 과체중
#
# 이름: 아파
# 몸무게: 91
# 키: 155
# BMI: 37.88
# 결과: 과체중
#
# 이름: 가나
# 몸무게: 77
# 키: 197
# BMI: 19.84
# 결과: 정상체중
#
# 이름: 라라
# 몸무게: 42
# 키: 161
# BMI: 16.20
# 결과: 저체중
#
# 이름: 파사
# 몸무게: 54
# 키: 193
# BMI: 14.50
# 결과: 저체중
#
# 이름: 하다
# 몸무게: 88
# 키: 186
# BMI: 25.44
# 결과: 과체중
#
# 이름: 자차
# 몸무게: 41
# 키: 162
# BMI: 15.62
# 결과: 저체중
#
# 이름: 나사
# 몸무게: 62
# 키: 140
# BMI: 31.63
# 결과: 과체중
#
# 이름: 나카
# 몸무게: 92
# 키: 185
# BMI: 26.88
# 결과: 과체중
#
# 이름: 라사
# 몸무게: 65
# 키: 140
# BMI: 33.16
# 결과: 과체중
#
# 이름: 마다
# 몸무게: 87
# 키: 150
# BMI: 38.67
# 결과: 과체중
#
# 이름: 아마
# 몸무게: 60
# 키: 141
# BMI: 30.18
# 결과: 과체중
#
# 이름: 마바
# 몸무게: 46
# 키: 169
# BMI: 16.11
# 결과: 저체중
#
# 이름: 타바
# 몸무게: 84
# 키: 180
# BMI: 25.93
# 결과: 과체중
#
# 이름: 타가
# 몸무게: 98
# 키: 178
# BMI: 30.93
# 결과: 과체중
#
# 이름: 나사
# 몸무게: 85
# 키: 193
# BMI: 22.82
# 결과: 정상체중
#
# 이름: 자자
# 몸무게: 86
# 키: 165
# BMI: 31.59
# 결과: 과체중
#
# 이름: 라자
# 몸무게: 76
# 키: 171
# BMI: 25.99
# 결과: 과체중
#
# 이름: 하자
# 몸무게: 67
# 키: 146
# BMI: 31.43
# 결과: 과체중
#
# 이름: 하파
# 몸무게: 74
# 키: 157
# BMI: 30.02
# 결과: 과체중
#
# 이름: 가가
# 몸무게: 96
# 키: 150
# BMI: 42.67
# 결과: 과체중
#
# 이름: 다카
# 몸무게: 91
# 키: 179
# BMI: 28.40
# 결과: 과체중
#
# 이름: 나마
# 몸무게: 48
# 키: 174
# BMI: 15.85
# 결과: 저체중
#
# 이름: 파라
# 몸무게: 96
# 키: 159
# BMI: 37.97
# 결과: 과체중
#
# 이름: 가차
# 몸무게: 52
# 키: 140
# BMI: 26.53
# 결과: 과체중
#
# 이름: 파사
# 몸무게: 64
# 키: 143
# BMI: 31.30
# 결과: 과체중
#
# 이름: 바사
# 몸무게: 75
# 키: 176
# BMI: 24.21
# 결과: 정상체중
#
# 이름: 나카
# 몸무게: 98
# 키: 142
# BMI: 48.60
# 결과: 과체중
#
# 이름: 차다
# 몸무게: 65
# 키: 169
# BMI: 22.76
# 결과: 정상체중
#
# 이름: 타마
# 몸무게: 43
# 키: 169
# BMI: 15.06
# 결과: 저체중
#
# 이름: 하마
# 몸무게: 83
# 키: 186
# BMI: 23.99
# 결과: 정상체중
#
# 이름: 마아
# 몸무게: 41
# 키: 191
# BMI: 11.24
# 결과: 저체중
#
# 이름: 아차
# 몸무게: 95
# 키: 194
# BMI: 25.24
# 결과: 과체중
#
# 이름: 카바
# 몸무게: 79
# 키: 183
# BMI: 23.59
# 결과: 정상체중
#
# 이름: 바아
# 몸무게: 50
# 키: 178
# BMI: 15.78
# 결과: 저체중
#
# 이름: 타다
# 몸무게: 70
# 키: 180
# BMI: 21.60
# 결과: 정상체중
#
# 이름: 라바
# 몸무게: 70
# 키: 161
# BMI: 27.01
# 결과: 과체중
#
# 이름: 나가
# 몸무게: 52
# 키: 148
# BMI: 23.74
# 결과: 정상체중
#
# 이름: 가사
# 몸무게: 55
# 키: 180
# BMI: 16.98
# 결과: 저체중
#
# 이름: 차자
# 몸무게: 61
# 키: 153
# BMI: 26.06
# 결과: 과체중
#
# 이름: 하가
# 몸무게: 48
# 키: 168
# BMI: 17.01
# 결과: 저체중
#
# 이름: 바나
# 몸무게: 57
# 키: 168
# BMI: 20.20
# 결과: 정상체중
#
# 이름: 라가
# 몸무게: 51
# 키: 194
# BMI: 13.55
# 결과: 저체중
#
# 이름: 차파
# 몸무게: 51
# 키: 164
# BMI: 18.96
# 결과: 정상체중
#
# 이름: 카차
# 몸무게: 66
# 키: 184
# BMI: 19.49
# 결과: 정상체중
#
# 이름: 카카
# 몸무게: 88
# 키: 161
# BMI: 33.95
# 결과: 과체중
#
# 이름: 카카
# 몸무게: 52
# 키: 193
# BMI: 13.96
# 결과: 저체중
#
# 이름: 나다
# 몸무게: 93
# 키: 160
# BMI: 36.33
# 결과: 과체중
#
# 이름: 마나
# 몸무게: 73
# 키: 177
# BMI: 23.30
# 결과: 정상체중
#
# 이름: 차마
# 몸무게: 95
# 키: 151
# BMI: 41.66
# 결과: 과체중
#
# 이름: 하차
# 몸무게: 55
# 키: 153
# BMI: 23.50
# 결과: 정상체중
#
# 이름: 다차
# 몸무게: 96
# 키: 152
# BMI: 41.55
# 결과: 과체중
#
# 이름: 파자
# 몸무게: 77
# 키: 143
# BMI: 37.65
# 결과: 과체중
#
# 이름: 바나
# 몸무게: 64
# 키: 176
# BMI: 20.66
# 결과: 정상체중
#
# 이름: 아하
# 몸무게: 91
# 키: 193
# BMI: 24.43
# 결과: 정상체중
#
# 이름: 하나
# 몸무게: 62
# 키: 152
# BMI: 26.84
# 결과: 과체중
#
# 이름: 가아
# 몸무게: 58
# 키: 185
# BMI: 16.95
# 결과: 저체중
#
# 이름: 나하
# 몸무게: 88
# 키: 185
# BMI: 25.71
# 결과: 과체중
#
# 이름: 마차
# 몸무게: 60
# 키: 182
# BMI: 18.11
# 결과: 저체중
#
# 이름: 자마
# 몸무게: 53
# 키: 184
# BMI: 15.65
# 결과: 저체중
#
# 이름: 카가
# 몸무게: 58
# 키: 159
# BMI: 22.94
# 결과: 정상체중
#
# 이름: 다가
# 몸무게: 55
# 키: 174
# BMI: 18.17
# 결과: 저체중
#
# 이름: 나파
# 몸무게: 83
# 키: 160
# BMI: 32.42
# 결과: 과체중
#
# 이름: 아카
# 몸무게: 50
# 키: 170
# BMI: 17.30
# 결과: 저체중
#
# 이름: 사사
# 몸무게: 70
# 키: 140
# BMI: 35.71
# 결과: 과체중
#
# 이름: 다하
# 몸무게: 65
# 키: 173
# BMI: 21.72
# 결과: 정상체중
#
# 이름: 카바
# 몸무게: 87
# 키: 196
# BMI: 22.65
# 결과: 정상체중
#
# 이름: 다라
# 몸무게: 67
# 키: 198
# BMI: 17.09
# 결과: 저체중
#
# 이름: 바자
# 몸무게: 42
# 키: 196
# BMI: 10.93
# 결과: 저체중
#
# 이름: 마사
# 몸무게: 77
# 키: 152
# BMI: 33.33
# 결과: 과체중
#
# 이름: 다라
# 몸무게: 46
# 키: 198
# BMI: 11.73
# 결과: 저체중
#
# 이름: 아나
# 몸무게: 50
# 키: 142
# BMI: 24.80
# 결과: 정상체중
#
# 이름: 바나
# 몸무게: 59
# 키: 179
# BMI: 18.41
# 결과: 저체중
#
# 이름: 차타
# 몸무게: 78
# 키: 196
# BMI: 20.30
# 결과: 정상체중
#
# 이름: 아하
# 몸무게: 60
# 키: 187
# BMI: 17.16
# 결과: 저체중
#
# 이름: 아자
# 몸무게: 63
# 키: 178
# BMI: 19.88
# 결과: 정상체중
#
# 이름: 나라
# 몸무게: 67
# 키: 166
# BMI: 24.31
# 결과: 정상체중
#
# 이름: 카타
# 몸무게: 62
# 키: 191
# BMI: 17.00
# 결과: 저체중
#
# 이름: 자하
# 몸무게: 61
# 키: 197
# BMI: 15.72
# 결과: 저체중
#
# 이름: 바마
# 몸무게: 44
# 키: 183
# BMI: 13.14
# 결과: 저체중
#
# 이름: 가라
# 몸무게: 86
# 키: 164
# BMI: 31.98
# 결과: 과체중
#
# 이름: 다카
# 몸무게: 59
# 키: 162
# BMI: 22.48
# 결과: 정상체중
#
# 이름: 나카
# 몸무게: 68
# 키: 195
# BMI: 17.88
# 결과: 저체중
#
# 이름: 하자
# 몸무게: 54
# 키: 148
# BMI: 24.65
# 결과: 정상체중
#
# 이름: 파다
# 몸무게: 90
# 키: 142
# BMI: 44.63
# 결과: 과체중
#
# 이름: 나가
# 몸무게: 87
# 키: 165
# BMI: 31.96
# 결과: 과체중
#
# 이름: 바아
# 몸무게: 80
# 키: 180
# BMI: 24.69
# 결과: 정상체중
#
# 이름: 사가
# 몸무게: 99
# 키: 167
# BMI: 35.50
# 결과: 과체중
#
# 이름: 마자
# 몸무게: 98
# 키: 160
# BMI: 38.28
# 결과: 과체중
#
# 이름: 하가
# 몸무게: 60
# 키: 199
# BMI: 15.15
# 결과: 저체중
#
# 이름: 나타
# 몸무게: 96
# 키: 163
# BMI: 36.13
# 결과: 과체중
#
# 이름: 가라
# 몸무게: 91
# 키: 162
# BMI: 34.67
# 결과: 과체중
#
# 이름: 나다
# 몸무게: 59
# 키: 165
# BMI: 21.67
# 결과: 정상체중
#
# 이름: 차사
# 몸무게: 42
# 키: 147
# BMI: 19.44
# 결과: 정상체중
#
# 이름: 라나
# 몸무게: 55
# 키: 151
# BMI: 24.12
# 결과: 정상체중
#
# 이름: 타다
# 몸무게: 68
# 키: 181
# BMI: 20.76
# 결과: 정상체중
#
# 이름: 타아
# 몸무게: 45
# 키: 157
# BMI: 18.26
# 결과: 저체중
#
# 이름: 아다
# 몸무게: 70
# 키: 147
# BMI: 32.39
# 결과: 과체중
#
# 이름: 차사
# 몸무게: 54
# 키: 185
# BMI: 15.78
# 결과: 저체중
#
# 이름: 가하
# 몸무게: 99
# 키: 192
# BMI: 26.86
# 결과: 과체중
#
# 이름: 아나
# 몸무게: 76
# 키: 188
# BMI: 21.50
# 결과: 정상체중
#
# 이름: 사차
# 몸무게: 79
# 키: 194
# BMI: 20.99
# 결과: 정상체중
#
# 이름: 바파
# 몸무게: 46
# 키: 195
# BMI: 12.10
# 결과: 저체중
#
# 이름: 바차
# 몸무게: 68
# 키: 187
# BMI: 19.45
# 결과: 정상체중
#
# 이름: 파아
# 몸무게: 48
# 키: 149
# BMI: 21.62
# 결과: 정상체중
#
# 이름: 사카
# 몸무게: 61
# 키: 178
# BMI: 19.25
# 결과: 정상체중
#
# 이름: 마라
# 몸무게: 45
# 키: 197
# BMI: 11.60
# 결과: 저체중
#
# 이름: 다마
# 몸무게: 93
# 키: 195
# BMI: 24.46
# 결과: 정상체중
#
# 이름: 하하
# 몸무게: 58
# 키: 170
# BMI: 20.07
# 결과: 정상체중
#
# 이름: 사가
# 몸무게: 65
# 키: 183
# BMI: 19.41
# 결과: 정상체중
#
# 이름: 자사
# 몸무게: 59
# 키: 153
# BMI: 25.20
# 결과: 과체중
#
# 이름: 차아
# 몸무게: 48
# 키: 181
# BMI: 14.65
# 결과: 저체중
#
# 이름: 파나
# 몸무게: 61
# 키: 185
# BMI: 17.82
# 결과: 저체중
#
# 이름: 마바
# 몸무게: 92
# 키: 148
# BMI: 42.00
# 결과: 과체중
#
# 이름: 사나
# 몸무게: 94
# 키: 191
# BMI: 25.77
# 결과: 과체중
#
# 이름: 마파
# 몸무게: 76
# 키: 174
# BMI: 25.10
# 결과: 과체중
#
# 이름: 마자
# 몸무게: 55
# 키: 144
# BMI: 26.52
# 결과: 과체중
#
# 이름: 마하
# 몸무게: 70
# 키: 168
# BMI: 24.80
# 결과: 정상체중
#
# 이름: 사카
# 몸무게: 66
# 키: 172
# BMI: 22.31
# 결과: 정상체중
#
# 이름: 하자
# 몸무게: 59
# 키: 172
# BMI: 19.94
# 결과: 정상체중
#
# 이름: 자나
# 몸무게: 69
# 키: 176
# BMI: 22.28
# 결과: 정상체중
#
# 이름: 카나
# 몸무게: 65
# 키: 158
# BMI: 26.04
# 결과: 과체중
#
# 이름: 아파
# 몸무게: 44
# 키: 141
# BMI: 22.13
# 결과: 정상체중
#
# 이름: 파나
# 몸무게: 52
# 키: 166
# BMI: 18.87
# 결과: 정상체중
#
# 이름: 라자
# 몸무게: 89
# 키: 143
# BMI: 43.52
# 결과: 과체중
#
# 이름: 바사
# 몸무게: 80
# 키: 142
# BMI: 39.67
# 결과: 과체중
#
# 이름: 가차
# 몸무게: 50
# 키: 186
# BMI: 14.45
# 결과: 저체중
#
# 이름: 아마
# 몸무게: 90
# 키: 173
# BMI: 30.07
# 결과: 과체중
#
# 이름: 다라
# 몸무게: 88
# 키: 176
# BMI: 28.41
# 결과: 과체중
#
# 이름: 마타
# 몸무게: 45
# 키: 148
# BMI: 20.54
# 결과: 정상체중
#
# 이름: 카나
# 몸무게: 90
# 키: 140
# BMI: 45.92
# 결과: 과체중
#
# 이름: 사라
# 몸무게: 46
# 키: 176
# BMI: 14.85
# 결과: 저체중
#
# 이름: 하하
# 몸무게: 48
# 키: 166
# BMI: 17.42
# 결과: 저체중
#
# 이름: 아나
# 몸무게: 72
# 키: 174
# BMI: 23.78
# 결과: 정상체중
#
# 이름: 차라
# 몸무게: 64
# 키: 196
# BMI: 16.66
# 결과: 저체중
#
# 이름: 사사
# 몸무게: 97
# 키: 198
# BMI: 24.74
# 결과: 정상체중
#
# 이름: 나아
# 몸무게: 45
# 키: 175
# BMI: 14.69
# 결과: 저체중
#
# 이름: 파마
# 몸무게: 67
# 키: 174
# BMI: 22.13
# 결과: 정상체중
#
# 이름: 타아
# 몸무게: 93
# 키: 171
# BMI: 31.80
# 결과: 과체중
#
# 이름: 타자
# 몸무게: 80
# 키: 144
# BMI: 38.58
# 결과: 과체중
#
# 이름: 하자
# 몸무게: 52
# 키: 168
# BMI: 18.42
# 결과: 저체중
#
# 이름: 타차
# 몸무게: 68
# 키: 170
# BMI: 23.53
# 결과: 정상체중
#
# 이름: 자바
# 몸무게: 88
# 키: 169
# BMI: 30.81
# 결과: 과체중
#
# 이름: 카바
# 몸무게: 60
# 키: 165
# BMI: 22.04
# 결과: 정상체중
#
# 이름: 마아
# 몸무게: 49
# 키: 182
# BMI: 14.79
# 결과: 저체중
#
# 이름: 가카
# 몸무게: 54
# 키: 142
# BMI: 26.78
# 결과: 과체중
#
# 이름: 자아
# 몸무게: 54
# 키: 179
# BMI: 16.85
# 결과: 저체중
#
# 이름: 가아
# 몸무게: 73
# 키: 188
# BMI: 20.65
# 결과: 정상체중
#
# 이름: 하하
# 몸무게: 81
# 키: 178
# BMI: 25.56
# 결과: 과체중
#
# 이름: 카라
# 몸무게: 42
# 키: 172
# BMI: 14.20
# 결과: 저체중
#
# 이름: 파아
# 몸무게: 63
# 키: 167
# BMI: 22.59
# 결과: 정상체중
#
# 이름: 다사
# 몸무게: 82
# 키: 185
# BMI: 23.96
# 결과: 정상체중
#
# 이름: 다타
# 몸무게: 94
# 키: 142
# BMI: 46.62
# 결과: 과체중
#
# 이름: 타타
# 몸무게: 84
# 키: 195
# BMI: 22.09
# 결과: 정상체중
#
# 이름: 카아
# 몸무게: 44
# 키: 157
# BMI: 17.85
# 결과: 저체중
#
# 이름: 사카
# 몸무게: 65
# 키: 142
# BMI: 32.24
# 결과: 과체중
#
# 이름: 다파
# 몸무게: 77
# 키: 150
# BMI: 34.22
# 결과: 과체중
#
# 이름: 아타
# 몸무게: 66
# 키: 154
# BMI: 27.83
# 결과: 과체중
#
# 이름: 다라
# 몸무게: 87
# 키: 193
# BMI: 23.36
# 결과: 정상체중
#
# 이름: 파아
# 몸무게: 69
# 키: 169
# BMI: 24.16
# 결과: 정상체중
#
# 이름: 라타
# 몸무게: 60
# 키: 189
# BMI: 16.80
# 결과: 저체중
#
# 이름: 파카
# 몸무게: 47
# 키: 182
# BMI: 14.19
# 결과: 저체중
#
# 이름: 차파
# 몸무게: 44
# 키: 163
# BMI: 16.56
# 결과: 저체중
#
# 이름: 아라
# 몸무게: 41
# 키: 171
# BMI: 14.02
# 결과: 저체중
#
# 이름: 하타
# 몸무게: 67
# 키: 148
# BMI: 30.59
# 결과: 과체중
#
# 이름: 라카
# 몸무게: 42
# 키: 157
# BMI: 17.04
# 결과: 저체중
#
# 이름: 사파
# 몸무게: 53
# 키: 185
# BMI: 15.49
# 결과: 저체중
#
# 이름: 타나
# 몸무게: 61
# 키: 179
# BMI: 19.04
# 결과: 정상체중
#
# 이름: 나사
# 몸무게: 95
# 키: 167
# BMI: 34.06
# 결과: 과체중
#
# 이름: 차차
# 몸무게: 49
# 키: 193
# BMI: 13.15
# 결과: 저체중
#
# 이름: 다자
# 몸무게: 55
# 키: 171
# BMI: 18.81
# 결과: 정상체중
#
# 이름: 아타
# 몸무게: 57
# 키: 194
# BMI: 15.15
# 결과: 저체중
#
# 이름: 마마
# 몸무게: 62
# 키: 169
# BMI: 21.71
# 결과: 정상체중
#
# 이름: 사사
# 몸무게: 61
# 키: 155
# BMI: 25.39
# 결과: 과체중
#
# 이름: 바사
# 몸무게: 98
# 키: 181
# BMI: 29.91
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 85
# 키: 194
# BMI: 22.58
# 결과: 정상체중
#
# 이름: 가자
# 몸무게: 94
# 키: 162
# BMI: 35.82
# 결과: 과체중
#
# 이름: 다라
# 몸무게: 48
# 키: 140
# BMI: 24.49
# 결과: 정상체중
#
# 이름: 나하
# 몸무게: 73
# 키: 178
# BMI: 23.04
# 결과: 정상체중
#
# 이름: 하카
# 몸무게: 50
# 키: 153
# BMI: 21.36
# 결과: 정상체중
#
# 이름: 파가
# 몸무게: 98
# 키: 185
# BMI: 28.63
# 결과: 과체중
#
# 이름: 자파
# 몸무게: 68
# 키: 177
# BMI: 21.71
# 결과: 정상체중
#
# 이름: 바타
# 몸무게: 54
# 키: 170
# BMI: 18.69
# 결과: 정상체중
#
# 이름: 카카
# 몸무게: 83
# 키: 185
# BMI: 24.25
# 결과: 정상체중
#
# 이름: 카파
# 몸무게: 99
# 키: 189
# BMI: 27.71
# 결과: 과체중
#
# 이름: 하카
# 몸무게: 96
# 키: 146
# BMI: 45.04
# 결과: 과체중
#
# 이름: 차사
# 몸무게: 89
# 키: 182
# BMI: 26.87
# 결과: 과체중
#
# 이름: 사차
# 몸무게: 80
# 키: 195
# BMI: 21.04
# 결과: 정상체중
#
# 이름: 하자
# 몸무게: 50
# 키: 196
# BMI: 13.02
# 결과: 저체중
#
# 이름: 마카
# 몸무게: 68
# 키: 155
# BMI: 28.30
# 결과: 과체중
#
# 이름: 가아
# 몸무게: 51
# 키: 183
# BMI: 15.23
# 결과: 저체중
#
# 이름: 나타
# 몸무게: 84
# 키: 162
# BMI: 32.01
# 결과: 과체중
#
# 이름: 자타
# 몸무게: 53
# 키: 199
# BMI: 13.38
# 결과: 저체중
#
# 이름: 아가
# 몸무게: 77
# 키: 190
# BMI: 21.33
# 결과: 정상체중
#
# 이름: 차가
# 몸무게: 92
# 키: 191
# BMI: 25.22
# 결과: 과체중
#
# 이름: 바나
# 몸무게: 43
# 키: 151
# BMI: 18.86
# 결과: 정상체중
#
# 이름: 다바
# 몸무게: 86
# 키: 153
# BMI: 36.74
# 결과: 과체중
#
# 이름: 가나
# 몸무게: 56
# 키: 173
# BMI: 18.71
# 결과: 정상체중
#
# 이름: 카나
# 몸무게: 50
# 키: 145
# BMI: 23.78
# 결과: 정상체중
#
# 이름: 바타
# 몸무게: 55
# 키: 196
# BMI: 14.32
# 결과: 저체중
#
# 이름: 바사
# 몸무게: 53
# 키: 169
# BMI: 18.56
# 결과: 정상체중
#
# 이름: 파마
# 몸무게: 97
# 키: 188
# BMI: 27.44
# 결과: 과체중
#
# 이름: 카아
# 몸무게: 95
# 키: 159
# BMI: 37.58
# 결과: 과체중
#
# 이름: 가라
# 몸무게: 91
# 키: 182
# BMI: 27.47
# 결과: 과체중
#
# 이름: 차하
# 몸무게: 52
# 키: 150
# BMI: 23.11
# 결과: 정상체중
#
# 이름: 차바
# 몸무게: 92
# 키: 176
# BMI: 29.70
# 결과: 과체중
#
# 이름: 아다
# 몸무게: 65
# 키: 160
# BMI: 25.39
# 결과: 과체중
#
# 이름: 하바
# 몸무게: 43
# 키: 165
# BMI: 15.79
# 결과: 저체중
#
# 이름: 하자
# 몸무게: 76
# 키: 143
# BMI: 37.17
# 결과: 과체중
#
# 이름: 자라
# 몸무게: 44
# 키: 144
# BMI: 21.22
# 결과: 정상체중
#
# 이름: 하바
# 몸무게: 61
# 키: 194
# BMI: 16.21
# 결과: 저체중
#
# 이름: 나다
# 몸무게: 69
# 키: 189
# BMI: 19.32
# 결과: 정상체중
#
# 이름: 라자
# 몸무게: 41
# 키: 166
# BMI: 14.88
# 결과: 저체중
#
# 이름: 아가
# 몸무게: 85
# 키: 165
# BMI: 31.22
# 결과: 과체중
#
# 이름: 카하
# 몸무게: 79
# 키: 192
# BMI: 21.43
# 결과: 정상체중
#
# 이름: 타가
# 몸무게: 49
# 키: 182
# BMI: 14.79
# 결과: 저체중
#
# 이름: 자하
# 몸무게: 86
# 키: 191
# BMI: 23.57
# 결과: 정상체중
#
# 이름: 나마
# 몸무게: 65
# 키: 145
# BMI: 30.92
# 결과: 과체중
#
# 이름: 카가
# 몸무게: 66
# 키: 175
# BMI: 21.55
# 결과: 정상체중
#
# 이름: 사나
# 몸무게: 66
# 키: 162
# BMI: 25.15
# 결과: 과체중
#
# 이름: 카카
# 몸무게: 64
# 키: 174
# BMI: 21.14
# 결과: 정상체중
#
# 이름: 라파
# 몸무게: 52
# 키: 173
# BMI: 17.37
# 결과: 저체중
#
# 이름: 타아
# 몸무게: 56
# 키: 172
# BMI: 18.93
# 결과: 정상체중
#
# 이름: 가가
# 몸무게: 88
# 키: 144
# BMI: 42.44
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 78
# 키: 147
# BMI: 36.10
# 결과: 과체중
#
# 이름: 사마
# 몸무게: 68
# 키: 180
# BMI: 20.99
# 결과: 정상체중
#
# 이름: 가바
# 몸무게: 80
# 키: 191
# BMI: 21.93
# 결과: 정상체중
#
# 이름: 나사
# 몸무게: 50
# 키: 199
# BMI: 12.63
# 결과: 저체중
#
# 이름: 카라
# 몸무게: 58
# 키: 178
# BMI: 18.31
# 결과: 저체중
#
# 이름: 하바
# 몸무게: 65
# 키: 183
# BMI: 19.41
# 결과: 정상체중
#
# 이름: 사사
# 몸무게: 51
# 키: 171
# BMI: 17.44
# 결과: 저체중
#
# 이름: 다하
# 몸무게: 65
# 키: 199
# BMI: 16.41
# 결과: 저체중
#
# 이름: 타파
# 몸무게: 59
# 키: 176
# BMI: 19.05
# 결과: 정상체중
#
# 이름: 바타
# 몸무게: 93
# 키: 146
# BMI: 43.63
# 결과: 과체중
#
# 이름: 나마
# 몸무게: 71
# 키: 199
# BMI: 17.93
# 결과: 저체중
#
# 이름: 자나
# 몸무게: 68
# 키: 161
# BMI: 26.23
# 결과: 과체중
#
# 이름: 하다
# 몸무게: 43
# 키: 176
# BMI: 13.88
# 결과: 저체중
#
# 이름: 파다
# 몸무게: 50
# 키: 160
# BMI: 19.53
# 결과: 정상체중
#
# 이름: 파나
# 몸무게: 42
# 키: 192
# BMI: 11.39
# 결과: 저체중
#
# 이름: 아아
# 몸무게: 40
# 키: 166
# BMI: 14.52
# 결과: 저체중
#
# 이름: 나가
# 몸무게: 88
# 키: 163
# BMI: 33.12
# 결과: 과체중
#
# 이름: 타자
# 몸무게: 51
# 키: 199
# BMI: 12.88
# 결과: 저체중
#
# 이름: 가라
# 몸무게: 63
# 키: 166
# BMI: 22.86
# 결과: 정상체중
#
# 이름: 아차
# 몸무게: 97
# 키: 179
# BMI: 30.27
# 결과: 과체중
#
# 이름: 카다
# 몸무게: 46
# 키: 160
# BMI: 17.97
# 결과: 저체중
#
# 이름: 나마
# 몸무게: 79
# 키: 177
# BMI: 25.22
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 84
# 키: 183
# BMI: 25.08
# 결과: 과체중
#
# 이름: 마라
# 몸무게: 52
# 키: 193
# BMI: 13.96
# 결과: 저체중
#
# 이름: 타자
# 몸무게: 64
# 키: 175
# BMI: 20.90
# 결과: 정상체중
#
# 이름: 타가
# 몸무게: 93
# 키: 181
# BMI: 28.39
# 결과: 과체중
#
# 이름: 카라
# 몸무게: 92
# 키: 170
# BMI: 31.83
# 결과: 과체중
#
# 이름: 파카
# 몸무게: 67
# 키: 146
# BMI: 31.43
# 결과: 과체중
#
# 이름: 타라
# 몸무게: 85
# 키: 178
# BMI: 26.83
# 결과: 과체중
#
# 이름: 마마
# 몸무게: 60
# 키: 167
# BMI: 21.51
# 결과: 정상체중
#
# 이름: 라나
# 몸무게: 47
# 키: 194
# BMI: 12.49
# 결과: 저체중
#
# 이름: 다타
# 몸무게: 88
# 키: 145
# BMI: 41.85
# 결과: 과체중
#
# 이름: 자파
# 몸무게: 81
# 키: 166
# BMI: 29.39
# 결과: 과체중
#
# 이름: 나아
# 몸무게: 58
# 키: 163
# BMI: 21.83
# 결과: 정상체중
#
# 이름: 자다
# 몸무게: 63
# 키: 163
# BMI: 23.71
# 결과: 정상체중
#
# 이름: 라차
# 몸무게: 43
# 키: 140
# BMI: 21.94
# 결과: 정상체중
#
# 이름: 바하
# 몸무게: 93
# 키: 144
# BMI: 44.85
# 결과: 과체중
#
# 이름: 가하
# 몸무게: 97
# 키: 147
# BMI: 44.89
# 결과: 과체중
#
# 이름: 사자
# 몸무게: 94
# 키: 171
# BMI: 32.15
# 결과: 과체중
#
# 이름: 차다
# 몸무게: 61
# 키: 146
# BMI: 28.62
# 결과: 과체중
#
# 이름: 자아
# 몸무게: 83
# 키: 148
# BMI: 37.89
# 결과: 과체중
#
# 이름: 라카
# 몸무게: 54
# 키: 158
# BMI: 21.63
# 결과: 정상체중
#
# 이름: 바하
# 몸무게: 89
# 키: 158
# BMI: 35.65
# 결과: 과체중
#
# 이름: 나파
# 몸무게: 92
# 키: 164
# BMI: 34.21
# 결과: 과체중
#
# 이름: 나자
# 몸무게: 88
# 키: 188
# BMI: 24.90
# 결과: 정상체중
#
# 이름: 가바
# 몸무게: 98
# 키: 191
# BMI: 26.86
# 결과: 과체중
#
# 이름: 사바
# 몸무게: 78
# 키: 189
# BMI: 21.84
# 결과: 정상체중
#
# 이름: 바사
# 몸무게: 77
# 키: 164
# BMI: 28.63
# 결과: 과체중
#
# 이름: 가라
# 몸무게: 87
# 키: 177
# BMI: 27.77
# 결과: 과체중
#
# 이름: 가차
# 몸무게: 51
# 키: 162
# BMI: 19.43
# 결과: 정상체중
#
# 이름: 바하
# 몸무게: 55
# 키: 153
# BMI: 23.50
# 결과: 정상체중
#
# 이름: 파다
# 몸무게: 84
# 키: 165
# BMI: 30.85
# 결과: 과체중
#
# 이름: 나다
# 몸무게: 66
# 키: 194
# BMI: 17.54
# 결과: 저체중
#
# 이름: 바카
# 몸무게: 97
# 키: 164
# BMI: 36.06
# 결과: 과체중
#
# 이름: 마마
# 몸무게: 86
# 키: 196
# BMI: 22.39
# 결과: 정상체중
#
# 이름: 바다
# 몸무게: 67
# 키: 164
# BMI: 24.91
# 결과: 정상체중
#
# 이름: 마나
# 몸무게: 41
# 키: 178
# BMI: 12.94
# 결과: 저체중
#
# 이름: 자아
# 몸무게: 55
# 키: 157
# BMI: 22.31
# 결과: 정상체중
#
# 이름: 사마
# 몸무게: 96
# 키: 188
# BMI: 27.16
# 결과: 과체중
#
# 이름: 가다
# 몸무게: 57
# 키: 173
# BMI: 19.05
# 결과: 정상체중
#
# 이름: 하바
# 몸무게: 51
# 키: 143
# BMI: 24.94
# 결과: 정상체중
#
# 이름: 마가
# 몸무게: 58
# 키: 183
# BMI: 17.32
# 결과: 저체중
#
# 이름: 사하
# 몸무게: 66
# 키: 146
# BMI: 30.96
# 결과: 과체중
#
# 이름: 아라
# 몸무게: 83
# 키: 171
# BMI: 28.38
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 96
# 키: 178
# BMI: 30.30
# 결과: 과체중
#
# 이름: 카하
# 몸무게: 82
# 키: 168
# BMI: 29.05
# 결과: 과체중
#
# 이름: 다하
# 몸무게: 68
# 키: 196
# BMI: 17.70
# 결과: 저체중
#
# 이름: 타파
# 몸무게: 65
# 키: 156
# BMI: 26.71
# 결과: 과체중
#
# 이름: 나사
# 몸무게: 56
# 키: 154
# BMI: 23.61
# 결과: 정상체중
#
# 이름: 카아
# 몸무게: 66
# 키: 168
# BMI: 23.38
# 결과: 정상체중
#
# 이름: 라마
# 몸무게: 50
# 키: 150
# BMI: 22.22
# 결과: 정상체중
#
# 이름: 나라
# 몸무게: 88
# 키: 168
# BMI: 31.18
# 결과: 과체중
#
# 이름: 가나
# 몸무게: 52
# 키: 153
# BMI: 22.21
# 결과: 정상체중
#
# 이름: 마차
# 몸무게: 61
# 키: 166
# BMI: 22.14
# 결과: 정상체중
#
# 이름: 나바
# 몸무게: 88
# 키: 173
# BMI: 29.40
# 결과: 과체중
#
# 이름: 하다
# 몸무게: 40
# 키: 175
# BMI: 13.06
# 결과: 저체중
#
# 이름: 나자
# 몸무게: 51
# 키: 189
# BMI: 14.28
# 결과: 저체중
#
# 이름: 바타
# 몸무게: 64
# 키: 195
# BMI: 16.83
# 결과: 저체중
#
# 이름: 다타
# 몸무게: 81
# 키: 163
# BMI: 30.49
# 결과: 과체중
#
# 이름: 아자
# 몸무게: 86
# 키: 159
# BMI: 34.02
# 결과: 과체중
#
# 이름: 하타
# 몸무게: 44
# 키: 194
# BMI: 11.69
# 결과: 저체중
#
# 이름: 라카
# 몸무게: 90
# 키: 170
# BMI: 31.14
# 결과: 과체중
#
# 이름: 타마
# 몸무게: 94
# 키: 170
# BMI: 32.53
# 결과: 과체중
#
# 이름: 아타
# 몸무게: 77
# 키: 184
# BMI: 22.74
# 결과: 정상체중
#
# 이름: 마아
# 몸무게: 81
# 키: 142
# BMI: 40.17
# 결과: 과체중
#
# 이름: 나라
# 몸무게: 92
# 키: 143
# BMI: 44.99
# 결과: 과체중
#
# 이름: 카파
# 몸무게: 96
# 키: 164
# BMI: 35.69
# 결과: 과체중
#
# 이름: 자자
# 몸무게: 40
# 키: 194
# BMI: 10.63
# 결과: 저체중
#
# 이름: 마차
# 몸무게: 82
# 키: 192
# BMI: 22.24
# 결과: 정상체중
#
# 이름: 하하
# 몸무게: 99
# 키: 155
# BMI: 41.21
# 결과: 과체중
#
# 이름: 사나
# 몸무게: 64
# 키: 168
# BMI: 22.68
# 결과: 정상체중
#
# 이름: 사카
# 몸무게: 51
# 키: 174
# BMI: 16.85
# 결과: 저체중
#
# 이름: 타사
# 몸무게: 68
# 키: 154
# BMI: 28.67
# 결과: 과체중
#
# 이름: 마타
# 몸무게: 58
# 키: 182
# BMI: 17.51
# 결과: 저체중
#
# 이름: 하하
# 몸무게: 95
# 키: 178
# BMI: 29.98
# 결과: 과체중
#
# 이름: 마타
# 몸무게: 76
# 키: 141
# BMI: 38.23
# 결과: 과체중
#
# 이름: 라다
# 몸무게: 71
# 키: 142
# BMI: 35.21
# 결과: 과체중
#
# 이름: 타카
# 몸무게: 69
# 키: 168
# BMI: 24.45
# 결과: 정상체중
#
# 이름: 나자
# 몸무게: 71
# 키: 186
# BMI: 20.52
# 결과: 정상체중
#
# 이름: 차마
# 몸무게: 70
# 키: 199
# BMI: 17.68
# 결과: 저체중
#
# 이름: 가마
# 몸무게: 71
# 키: 185
# BMI: 20.75
# 결과: 정상체중
#
# 이름: 나카
# 몸무게: 78
# 키: 166
# BMI: 28.31
# 결과: 과체중
#
# 이름: 다사
# 몸무게: 95
# 키: 168
# BMI: 33.66
# 결과: 과체중
#
# 이름: 가가
# 몸무게: 91
# 키: 150
# BMI: 40.44
# 결과: 과체중
#
# 이름: 아가
# 몸무게: 99
# 키: 172
# BMI: 33.46
# 결과: 과체중
#
# 이름: 나카
# 몸무게: 96
# 키: 157
# BMI: 38.95
# 결과: 과체중
#
# 이름: 사라
# 몸무게: 86
# 키: 169
# BMI: 30.11
# 결과: 과체중
#
# 이름: 마자
# 몸무게: 76
# 키: 195
# BMI: 19.99
# 결과: 정상체중
#
# 이름: 카바
# 몸무게: 59
# 키: 155
# BMI: 24.56
# 결과: 정상체중
#
# 이름: 자아
# 몸무게: 65
# 키: 147
# BMI: 30.08
# 결과: 과체중
#
# 이름: 파자
# 몸무게: 43
# 키: 167
# BMI: 15.42
# 결과: 저체중
#
# 이름: 마가
# 몸무게: 50
# 키: 148
# BMI: 22.83
# 결과: 정상체중
#
# 이름: 타아
# 몸무게: 79
# 키: 188
# BMI: 22.35
# 결과: 정상체중
#
# 이름: 아라
# 몸무게: 40
# 키: 184
# BMI: 11.81
# 결과: 저체중
#
# 이름: 라아
# 몸무게: 55
# 키: 188
# BMI: 15.56
# 결과: 저체중
#
# 이름: 차타
# 몸무게: 74
# 키: 173
# BMI: 24.73
# 결과: 정상체중
#
# 이름: 자바
# 몸무게: 61
# 키: 190
# BMI: 16.90
# 결과: 저체중
#
# 이름: 아하
# 몸무게: 81
# 키: 161
# BMI: 31.25
# 결과: 과체중
#
# 이름: 다차
# 몸무게: 78
# 키: 187
# BMI: 22.31
# 결과: 정상체중
#
# 이름: 하아
# 몸무게: 43
# 키: 180
# BMI: 13.27
# 결과: 저체중
#
# 이름: 나카
# 몸무게: 62
# 키: 164
# BMI: 23.05
# 결과: 정상체중
#
# 이름: 바가
# 몸무게: 83
# 키: 194
# BMI: 22.05
# 결과: 정상체중
#
# 이름: 나다
# 몸무게: 53
# 키: 171
# BMI: 18.13
# 결과: 저체중
#
# 이름: 가라
# 몸무게: 94
# 키: 192
# BMI: 25.50
# 결과: 과체중
#
# 이름: 카파
# 몸무게: 84
# 키: 187
# BMI: 24.02
# 결과: 정상체중
#
# 이름: 자사
# 몸무게: 43
# 키: 192
# BMI: 11.66
# 결과: 저체중
#
# 이름: 카카
# 몸무게: 82
# 키: 144
# BMI: 39.54
# 결과: 과체중
#
# 이름: 차파
# 몸무게: 70
# 키: 189
# BMI: 19.60
# 결과: 정상체중
#
# 이름: 타가
# 몸무게: 89
# 키: 172
# BMI: 30.08
# 결과: 과체중
#
# 이름: 가라
# 몸무게: 63
# 키: 175
# BMI: 20.57
# 결과: 정상체중
#
# 이름: 카아
# 몸무게: 62
# 키: 177
# BMI: 19.79
# 결과: 정상체중
#
# 이름: 차라
# 몸무게: 99
# 키: 177
# BMI: 31.60
# 결과: 과체중
#
# 이름: 나자
# 몸무게: 57
# 키: 159
# BMI: 22.55
# 결과: 정상체중
#
# 이름: 마카
# 몸무게: 63
# 키: 155
# BMI: 26.22
# 결과: 과체중
#
# 이름: 가아
# 몸무게: 78
# 키: 192
# BMI: 21.16
# 결과: 정상체중
#
# 이름: 파바
# 몸무게: 52
# 키: 189
# BMI: 14.56
# 결과: 저체중
#
# 이름: 사하
# 몸무게: 55
# 키: 147
# BMI: 25.45
# 결과: 과체중
#
# 이름: 마파
# 몸무게: 90
# 키: 176
# BMI: 29.05
# 결과: 과체중
#
# 이름: 하차
# 몸무게: 58
# 키: 166
# BMI: 21.05
# 결과: 정상체중
#
# 이름: 라자
# 몸무게: 82
# 키: 176
# BMI: 26.47
# 결과: 과체중
#
# 이름: 다타
# 몸무게: 80
# 키: 156
# BMI: 32.87
# 결과: 과체중
#
# 이름: 나다
# 몸무게: 45
# 키: 190
# BMI: 12.47
# 결과: 저체중
#
# 이름: 자다
# 몸무게: 44
# 키: 158
# BMI: 17.63
# 결과: 저체중
#
# 이름: 사사
# 몸무게: 91
# 키: 160
# BMI: 35.55
# 결과: 과체중
#
# 이름: 가자
# 몸무게: 79
# 키: 154
# BMI: 33.31
# 결과: 과체중
#
# 이름: 타마
# 몸무게: 66
# 키: 168
# BMI: 23.38
# 결과: 정상체중
#
# 이름: 나차
# 몸무게: 56
# 키: 173
# BMI: 18.71
# 결과: 정상체중
#
# 이름: 나라
# 몸무게: 90
# 키: 186
# BMI: 26.01
# 결과: 과체중
#
# 이름: 하파
# 몸무게: 54
# 키: 162
# BMI: 20.58
# 결과: 정상체중
#
# 이름: 파차
# 몸무게: 91
# 키: 164
# BMI: 33.83
# 결과: 과체중
#
# 이름: 하나
# 몸무게: 99
# 키: 155
# BMI: 41.21
# 결과: 과체중
#
# 이름: 카아
# 몸무게: 88
# 키: 147
# BMI: 40.72
# 결과: 과체중
#
# 이름: 나파
# 몸무게: 46
# 키: 186
# BMI: 13.30
# 결과: 저체중
#
# 이름: 가라
# 몸무게: 74
# 키: 147
# BMI: 34.24
# 결과: 과체중
#
# 이름: 자카
# 몸무게: 79
# 키: 153
# BMI: 33.75
# 결과: 과체중
#
# 이름: 다나
# 몸무게: 88
# 키: 168
# BMI: 31.18
# 결과: 과체중
#
# 이름: 나가
# 몸무게: 61
# 키: 145
# BMI: 29.01
# 결과: 과체중
#
# 이름: 바자
# 몸무게: 85
# 키: 166
# BMI: 30.85
# 결과: 과체중
#
# 이름: 사아
# 몸무게: 50
# 키: 190
# BMI: 13.85
# 결과: 저체중
#
# 이름: 자아
# 몸무게: 71
# 키: 145
# BMI: 33.77
# 결과: 과체중
#
# 이름: 자바
# 몸무게: 67
# 키: 165
# BMI: 24.61
# 결과: 정상체중
#
# 이름: 하다
# 몸무게: 79
# 키: 151
# BMI: 34.65
# 결과: 과체중
#
# 이름: 다사
# 몸무게: 82
# 키: 163
# BMI: 30.86
# 결과: 과체중
#
# 이름: 바바
# 몸무게: 74
# 키: 189
# BMI: 20.72
# 결과: 정상체중
#
# 이름: 하차
# 몸무게: 42
# 키: 162
# BMI: 16.00
# 결과: 저체중
#
# 이름: 차라
# 몸무게: 60
# 키: 156
# BMI: 24.65
# 결과: 정상체중
#
# 이름: 파나
# 몸무게: 92
# 키: 174
# BMI: 30.39
# 결과: 과체중
#
# 이름: 아라
# 몸무게: 69
# 키: 145
# BMI: 32.82
# 결과: 과체중
#
# 이름: 마카
# 몸무게: 48
# 키: 193
# BMI: 12.89
# 결과: 저체중
#
# 이름: 파타
# 몸무게: 43
# 키: 173
# BMI: 14.37
# 결과: 저체중
#
# 이름: 하카
# 몸무게: 65
# 키: 173
# BMI: 21.72
# 결과: 정상체중
#
# 이름: 자타
# 몸무게: 76
# 키: 187
# BMI: 21.73
# 결과: 정상체중
#
# 이름: 가아
# 몸무게: 96
# 키: 198
# BMI: 24.49
# 결과: 정상체중
#
# 이름: 카라
# 몸무게: 79
# 키: 171
# BMI: 27.02
# 결과: 과체중
#
# 이름: 바나
# 몸무게: 94
# 키: 196
# BMI: 24.47
# 결과: 정상체중
#
# 이름: 다카
# 몸무게: 41
# 키: 150
# BMI: 18.22
# 결과: 저체중
#
# 이름: 사가
# 몸무게: 79
# 키: 195
# BMI: 20.78
# 결과: 정상체중
#
# 이름: 차자
# 몸무게: 93
# 키: 173
# BMI: 31.07
# 결과: 과체중
#
# 이름: 나나
# 몸무게: 82
# 키: 199
# BMI: 20.71
# 결과: 정상체중
#
# 이름: 가카
# 몸무게: 93
# 키: 160
# BMI: 36.33
# 결과: 과체중
#
# 이름: 하파
# 몸무게: 44
# 키: 191
# BMI: 12.06
# 결과: 저체중
#
# 이름: 나나
# 몸무게: 46
# 키: 187
# BMI: 13.15
# 결과: 저체중
#
# 이름: 파나
# 몸무게: 48
# 키: 181
# BMI: 14.65
# 결과: 저체중
#
# 이름: 자하
# 몸무게: 83
# 키: 164
# BMI: 30.86
# 결과: 과체중
#
# 이름: 아아
# 몸무게: 71
# 키: 148
# BMI: 32.41
# 결과: 과체중
#
# 이름: 카파
# 몸무게: 58
# 키: 157
# BMI: 23.53
# 결과: 정상체중
#
# 이름: 타하
# 몸무게: 46
# 키: 160
# BMI: 17.97
# 결과: 저체중
#
# 이름: 바다
# 몸무게: 59
# 키: 189
# BMI: 16.52
# 결과: 저체중
#
# 이름: 차타
# 몸무게: 49
# 키: 155
# BMI: 20.40
# 결과: 정상체중
#
# 이름: 파라
# 몸무게: 49
# 키: 189
# BMI: 13.72
# 결과: 저체중
#
# 이름: 하파
# 몸무게: 94
# 키: 148
# BMI: 42.91
# 결과: 과체중
#
# 이름: 자사
# 몸무게: 91
# 키: 186
# BMI: 26.30
# 결과: 과체중
#
# 이름: 라나
# 몸무게: 88
# 키: 185
# BMI: 25.71
# 결과: 과체중
#
# 이름: 아차
# 몸무게: 85
# 키: 185
# BMI: 24.84
# 결과: 정상체중
#
# 이름: 하마
# 몸무게: 92
# 키: 157
# BMI: 37.32
# 결과: 과체중
#
# 이름: 아파
# 몸무게: 96
# 키: 197
# BMI: 24.74
# 결과: 정상체중
#
# 이름: 아다
# 몸무게: 71
# 키: 188
# BMI: 20.09
# 결과: 정상체중
#
# 이름: 사파
# 몸무게: 52
# 키: 178
# BMI: 16.41
# 결과: 저체중
#
# 이름: 바카
# 몸무게: 85
# 키: 189
# BMI: 23.80
# 결과: 정상체중
#
# 이름: 타사
# 몸무게: 75
# 키: 167
# BMI: 26.89
# 결과: 과체중
#
# 이름: 다가
# 몸무게: 71
# 키: 196
# BMI: 18.48
# 결과: 저체중
#
# 이름: 사라
# 몸무게: 87
# 키: 169
# BMI: 30.46
# 결과: 과체중
#
# 이름: 라라
# 몸무게: 83
# 키: 155
# BMI: 34.55
# 결과: 과체중
#
# 이름: 다가
# 몸무게: 40
# 키: 181
# BMI: 12.21
# 결과: 저체중
#
# 이름: 사파
# 몸무게: 41
# 키: 187
# BMI: 11.72
# 결과: 저체중
#
# 이름: 파나
# 몸무게: 51
# 키: 175
# BMI: 16.65
# 결과: 저체중
#
# 이름: 차하
# 몸무게: 45
# 키: 193
# BMI: 12.08
# 결과: 저체중
#
# 이름: 나마
# 몸무게: 95
# 키: 141
# BMI: 47.78
# 결과: 과체중
#
# 이름: 사라
# 몸무게: 79
# 키: 196
# BMI: 20.56
# 결과: 정상체중
#
# 이름: 하다
# 몸무게: 85
# 키: 196
# BMI: 22.13
# 결과: 정상체중
#
# 이름: 라차
# 몸무게: 64
# 키: 175
# BMI: 20.90
# 결과: 정상체중
#
# 이름: 타라
# 몸무게: 88
# 키: 179
# BMI: 27.46
# 결과: 과체중
#
# 이름: 나바
# 몸무게: 54
# 키: 165
# BMI: 19.83
# 결과: 정상체중
#
# 이름: 자타
# 몸무게: 62
# 키: 149
# BMI: 27.93
# 결과: 과체중
#
# 이름: 아라
# 몸무게: 59
# 키: 150
# BMI: 26.22
# 결과: 과체중
#
# 이름: 차카
# 몸무게: 64
# 키: 189
# BMI: 17.92
# 결과: 저체중
#
# 이름: 차차
# 몸무게: 55
# 키: 195
# BMI: 14.46
# 결과: 저체중
#
# 이름: 카다
# 몸무게: 80
# 키: 183
# BMI: 23.89
# 결과: 정상체중
#
# 이름: 라사
# 몸무게: 43
# 키: 166
# BMI: 15.60
# 결과: 저체중
#
# 이름: 다자
# 몸무게: 81
# 키: 177
# BMI: 25.85
# 결과: 과체중
#
# 이름: 타자
# 몸무게: 81
# 키: 174
# BMI: 26.75
# 결과: 과체중
#
# 이름: 다아
# 몸무게: 95
# 키: 195
# BMI: 24.98
# 결과: 정상체중
#
# 이름: 라하
# 몸무게: 84
# 키: 159
# BMI: 33.23
# 결과: 과체중
#
# 이름: 아타
# 몸무게: 61
# 키: 198
# BMI: 15.56
# 결과: 저체중
#
# 이름: 하라
# 몸무게: 77
# 키: 193
# BMI: 20.67
# 결과: 정상체중
#
# 이름: 라마
# 몸무게: 96
# 키: 199
# BMI: 24.24
# 결과: 정상체중
#
# 이름: 차다
# 몸무게: 84
# 키: 141
# BMI: 42.25
# 결과: 과체중
#
# 이름: 자아
# 몸무게: 87
# 키: 160
# BMI: 33.98
# 결과: 과체중
#
# 이름: 바파
# 몸무게: 64
# 키: 171
# BMI: 21.89
# 결과: 정상체중
#
# 이름: 라마
# 몸무게: 57
# 키: 180
# BMI: 17.59
# 결과: 저체중
#
# 이름: 하아
# 몸무게: 56
# 키: 161
# BMI: 21.60
# 결과: 정상체중
#
# 이름: 아타
# 몸무게: 50
# 키: 169
# BMI: 17.51
# 결과: 저체중
#
# 이름: 차나
# 몸무게: 64
# 키: 145
# BMI: 30.44
# 결과: 과체중
#
# 이름: 카나
# 몸무게: 66
# 키: 151
# BMI: 28.95
# 결과: 과체중
#
# 이름: 다타
# 몸무게: 92
# 키: 163
# BMI: 34.63
# 결과: 과체중
#
# 이름: 아라
# 몸무게: 77
# 키: 193
# BMI: 20.67
# 결과: 정상체중
#
# 이름: 타다
# 몸무게: 47
# 키: 194
# BMI: 12.49
# 결과: 저체중
#
# 이름: 카하
# 몸무게: 52
# 키: 187
# BMI: 14.87
# 결과: 저체중
#
# 이름: 차다
# 몸무게: 77
# 키: 182
# BMI: 23.25
# 결과: 정상체중
#
# 이름: 라자
# 몸무게: 63
# 키: 178
# BMI: 19.88
# 결과: 정상체중
#
# 이름: 라타
# 몸무게: 96
# 키: 159
# BMI: 37.97
# 결과: 과체중
#
# 이름: 나바
# 몸무게: 95
# 키: 167
# BMI: 34.06
# 결과: 과체중
#
# 이름: 카하
# 몸무게: 88
# 키: 194
# BMI: 23.38
# 결과: 정상체중
#
# 이름: 나나
# 몸무게: 95
# 키: 141
# BMI: 47.78
# 결과: 과체중
#
# 이름: 카다
# 몸무게: 41
# 키: 185
# BMI: 11.98
# 결과: 저체중
#
# 이름: 아마
# 몸무게: 75
# 키: 142
# BMI: 37.20
# 결과: 과체중
#
# 이름: 카카
# 몸무게: 41
# 키: 168
# BMI: 14.53
# 결과: 저체중
#
# 이름: 다가
# 몸무게: 49
# 키: 153
# BMI: 20.93
# 결과: 정상체중
#
# 이름: 하가
# 몸무게: 98
# 키: 196
# BMI: 25.51
# 결과: 과체중
#
# 이름: 가카
# 몸무게: 49
# 키: 186
# BMI: 14.16
# 결과: 저체중
#
# 이름: 하라
# 몸무게: 60
# 키: 193
# BMI: 16.11
# 결과: 저체중
#
# 이름: 아차
# 몸무게: 59
# 키: 141
# BMI: 29.68
# 결과: 과체중
#
# 이름: 타타
# 몸무게: 66
# 키: 194
# BMI: 17.54
# 결과: 저체중
#
# 이름: 하나
# 몸무게: 51
# 키: 168
# BMI: 18.07
# 결과: 저체중
#
# 이름: 하나
# 몸무게: 73
# 키: 141
# BMI: 36.72
# 결과: 과체중
#
# 이름: 하마
# 몸무게: 46
# 키: 187
# BMI: 13.15
# 결과: 저체중
#
# 이름: 라가
# 몸무게: 67
# 키: 193
# BMI: 17.99
# 결과: 저체중
#
# 이름: 마마
# 몸무게: 76
# 키: 193
# BMI: 20.40
# 결과: 정상체중
#
# 이름: 바자
# 몸무게: 47
# 키: 153
# BMI: 20.08
# 결과: 정상체중
#
# 이름: 카카
# 몸무게: 73
# 키: 170
# BMI: 25.26
# 결과: 과체중
#
# 이름: 자자
# 몸무게: 49
# 키: 166
# BMI: 17.78
# 결과: 저체중
#
# 이름: 하아
# 몸무게: 93
# 키: 151
# BMI: 40.79
# 결과: 과체중
#
# 이름: 아마
# 몸무게: 77
# 키: 152
# BMI: 33.33
# 결과: 과체중
#
# 이름: 라바
# 몸무게: 58
# 키: 170
# BMI: 20.07
# 결과: 정상체중
#
# 이름: 사다
# 몸무게: 82
# 키: 178
# BMI: 25.88
# 결과: 과체중
#
# 이름: 가파
# 몸무게: 71
# 키: 176
# BMI: 22.92
# 결과: 정상체중
#
# 이름: 파다
# 몸무게: 78
# 키: 140
# BMI: 39.80
# 결과: 과체중
#
# 이름: 라타
# 몸무게: 67
# 키: 173
# BMI: 22.39
# 결과: 정상체중
#
# 이름: 타아
# 몸무게: 59
# 키: 154
# BMI: 24.88
# 결과: 정상체중
#
# 이름: 차마
# 몸무게: 54
# 키: 168
# BMI: 19.13
# 결과: 정상체중
#
# 이름: 카다
# 몸무게: 83
# 키: 149
# BMI: 37.39
# 결과: 과체중
#
# 이름: 하아
# 몸무게: 98
# 키: 181
# BMI: 29.91
# 결과: 과체중
#
# 이름: 사마
# 몸무게: 49
# 키: 154
# BMI: 20.66
# 결과: 정상체중
#
# 이름: 가하
# 몸무게: 85
# 키: 195
# BMI: 22.35
# 결과: 정상체중
#
# 이름: 카차
# 몸무게: 46
# 키: 148
# BMI: 21.00
# 결과: 정상체중
#
# 이름: 하하
# 몸무게: 93
# 키: 141
# BMI: 46.78
# 결과: 과체중
#
# 이름: 타파
# 몸무게: 81
# 키: 187
# BMI: 23.16
# 결과: 정상체중
#
# 이름: 타라
# 몸무게: 46
# 키: 168
# BMI: 16.30
# 결과: 저체중
#
# 이름: 파차
# 몸무게: 85
# 키: 156
# BMI: 34.93
# 결과: 과체중
#
# 이름: 다라
# 몸무게: 87
# 키: 160
# BMI: 33.98
# 결과: 과체중
#
# 이름: 다마
# 몸무게: 61
# 키: 181
# BMI: 18.62
# 결과: 정상체중
#
# 이름: 차차
# 몸무게: 85
# 키: 180
# BMI: 26.23
# 결과: 과체중
#
# 이름: 가다
# 몸무게: 87
# 키: 148
# BMI: 39.72
# 결과: 과체중
#
# 이름: 사나
# 몸무게: 41
# 키: 194
# BMI: 10.89
# 결과: 저체중
#
# 이름: 나자
# 몸무게: 62
# 키: 194
# BMI: 16.47
# 결과: 저체중
#
# 이름: 파타
# 몸무게: 88
# 키: 148
# BMI: 40.18
# 결과: 과체중
#
# 이름: 사가
# 몸무게: 65
# 키: 159
# BMI: 25.71
# 결과: 과체중
#
# 이름: 자바
# 몸무게: 83
# 키: 174
# BMI: 27.41
# 결과: 과체중
#
# 이름: 바가
# 몸무게: 74
# 키: 161
# BMI: 28.55
# 결과: 과체중
#
# 이름: 차바
# 몸무게: 65
# 키: 160
# BMI: 25.39
# 결과: 과체중
#
# 이름: 아차
# 몸무게: 99
# 키: 140
# BMI: 50.51
# 결과: 과체중
#
# 이름: 가바
# 몸무게: 67
# 키: 156
# BMI: 27.53
# 결과: 과체중
#
# 이름: 가사
# 몸무게: 96
# 키: 179
# BMI: 29.96
# 결과: 과체중
#
# 이름: 타다
# 몸무게: 45
# 키: 197
# BMI: 11.60
# 결과: 저체중
#
# 이름: 하나
# 몸무게: 87
# 키: 178
# BMI: 27.46
# 결과: 과체중
#
# 이름: 라카
# 몸무게: 69
# 키: 140
# BMI: 35.20
# 결과: 과체중
#
# 이름: 마가
# 몸무게: 97
# 키: 171
# BMI: 33.17
# 결과: 과체중
#
# 이름: 다마
# 몸무게: 86
# 키: 145
# BMI: 40.90
# 결과: 과체중
#
# 이름: 사자
# 몸무게: 55
# 키: 160
# BMI: 21.48
# 결과: 정상체중
#
# 이름: 타나
# 몸무게: 50
# 키: 158
# BMI: 20.03
# 결과: 정상체중
#
# 이름: 자나
# 몸무게: 49
# 키: 171
# BMI: 16.76
# 결과: 저체중
#
# 이름: 카마
# 몸무게: 71
# 키: 192
# BMI: 19.26
# 결과: 정상체중
#
# 이름: 파파
# 몸무게: 84
# 키: 157
# BMI: 34.08
# 결과: 과체중
#
# 이름: 마바
# 몸무게: 50
# 키: 156
# BMI: 20.55
# 결과: 정상체중
#
# 이름: 가자
# 몸무게: 95
# 키: 198
# BMI: 24.23
# 결과: 정상체중
#
# 이름: 사마
# 몸무게: 86
# 키: 167
# BMI: 30.84
# 결과: 과체중
#
# 이름: 타하
# 몸무게: 62
# 키: 162
# BMI: 23.62
# 결과: 정상체중
#
# 이름: 사마
# 몸무게: 45
# 키: 169
# BMI: 15.76
# 결과: 저체중
#
# 이름: 카자
# 몸무게: 60
# 키: 198
# BMI: 15.30
# 결과: 저체중
#
# 이름: 하타
# 몸무게: 85
# 키: 146
# BMI: 39.88
# 결과: 과체중
#
# 이름: 차나
# 몸무게: 51
# 키: 157
# BMI: 20.69
# 결과: 정상체중
#
# 이름: 다나
# 몸무게: 52
# 키: 148
# BMI: 23.74
# 결과: 정상체중
#
# 이름: 자가
# 몸무게: 57
# 키: 154
# BMI: 24.03
# 결과: 정상체중
#
# 이름: 다하
# 몸무게: 88
# 키: 144
# BMI: 42.44
# 결과: 과체중

# %%
# 이진 파일처리 - b

data = ""
with open("c:/windows/notepad.exe", "rb") as f1:
        data = f1.read()
with open("c:/windows/notepad.exe", "wb") as f2:
        f2.write(data)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-46-ddfe6db20856> in <module>
#       4 with open("c:/windows/notepad.exe", "rb") as f1:
#       5         data = f1.read()
# ----> 6 with open("c:/windows/notepad.exe", "wb") as f2:
#       7         f2.write(data)
#
# PermissionError: [Errno 13] Permission denied: 'c:/windows/notepad.exe'
